# %% [markdown]
# # Processing the data in a way that the system can understand

# %%
# !pip install pandas

import pandas as pd
import os
import re
# Out:
#   WARNING: The script f2py.exe is installed in 'C:\Users\iliya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\iliya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Collecting pandas
#   Downloading pandas-1.5.2-cp38-cp38-win_amd64.whl (11.0 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\iliya\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Collecting numpy>=1.20.3
#   Downloading numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
# Requirement already satisfied: six>=1.5 in c:\users\iliya\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.5 pandas-1.5.2 pytz-2022.6

# %% [markdown]
# ## Loading the requiert files
# - Which are the clean user annotations, and
# - The .csv file with the links and names of the wikipedia articles

# %%
clean_annotations = pd.read_csv('./clean_data/clean_annotations_without_duplicates.csv', encoding='utf-8')
annotation_doc_list = pd.read_csv('./BG_Documents.csv', encoding='utf-8')

# %%
len(set(clean_annotations['doc_id']))
# Out:
# 102

# %%
clean_annotations = clean_annotations[['doc_id','acronym', 'expansion','type']]
clean_annotations.drop_duplicates(keep='first', inplace=True, ignore_index=False)
clean_annotations.dropna(inplace=True)

# %%
out_expansion_df = clean_annotations[clean_annotations['type'] == 'out_expansion']
in_expansion_df = clean_annotations[clean_annotations['type'] == 'in_expansion']

# %%
in_expansion_df
len(set(in_expansion_df['doc_id']))
# Out:
# 55

# %%
in_expansion_df['In'] = in_expansion_df['acronym'] + ';' + in_expansion_df['expansion']+ str("\n")
in_expansion_df['In'] = in_expansion_df.groupby('doc_id')['In'].transform(lambda x: ''.join(x))

in_expansion_df_sub = in_expansion_df[['doc_id', 'In']].drop_duplicates()

in_expansion_df_sub.reset_index(inplace=True)
in_expansion_df_sub.index.name = 'DocID'


in_expansion_df_sub['Title'] = in_expansion_df_sub['doc_id'] 
in_expansion_df_sub['WikiID'] = in_expansion_df_sub['Title'].apply(hash)
in_expansion_df_sub['WikiID'] = in_expansion_df_sub['WikiID'].astype(str).str[1:10]
in_expansion_df_sub['In'] = in_expansion_df_sub['In'].str[:-1]

in_expansion_final = in_expansion_df_sub[['Title', 'WikiID', 'In']]

in_expansion_final.head()
# Out:
# C:\Users\iliya\AppData\Local\Temp\ipykernel_4684\2550237458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_expansion_df['In'] = in_expansion_df['acronym'] + ';' + in_expansion_df['expansion']+ str("\n")
# C:\Users\iliya\AppData\Local\Temp\ipykernel_4684\2550237458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_expansion_df['In'] = in_expansion_df.groupby('doc_id')['In'].transform(lambda x: ''.join(x))
#                                     Title     WikiID  \
# DocID
# 0                                     UML  708692214
# 1                     Административен_акт  165924315
# 2                    Акционерно_дружество  049006696
# 3      Американска_психологична_асоциация  909584298
# 4        Банкова_консолидационна_компания  367972283
#
#                                                       In
# DocID
# 0                            OMG;Object Management Group
# 1                 АПК;Административнопроцесуалния кодекс
# 2      АД;Акционерно дружество\nЕАД;еднолично акционе...
# 3               АПА;Американската психологична асоциация
# 4                 БКК;Банковата консолидационна компания

# %%
out_expansion_df['Out'] = out_expansion_df['acronym'] + ';' + out_expansion_df['expansion']+ str("\n")
out_expansion_df['Out'] = out_expansion_df.groupby('doc_id')['Out'].transform(lambda x: ''.join(x))

out_expansion_df_sub = out_expansion_df[['doc_id', 'Out']].drop_duplicates()

out_expansion_df_sub.reset_index(inplace=True)
out_expansion_df_sub.index.name = 'DocID'


out_expansion_df_sub['Title'] = out_expansion_df_sub['doc_id'] 
# out_expansion_df_sub['WikiID'] = out_expansion_df_sub['doc_id'] 

out_expansion_df_sub['WikiID'] = out_expansion_df_sub['Title'].apply(hash)
out_expansion_df_sub['WikiID'] = out_expansion_df_sub['WikiID'].astype(str).str[1:10]

out_expansion_df_sub['Out'] = out_expansion_df_sub['Out'].str[:-1]

out_expansion_final = out_expansion_df_sub[['Title', 'WikiID', 'Out']]

out_expansion_final.head()
# Out:
# C:\Users\iliya\AppData\Local\Temp\ipykernel_4684\364060586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_expansion_df['Out'] = out_expansion_df['acronym'] + ';' + out_expansion_df['expansion']+ str("\n")
# C:\Users\iliya\AppData\Local\Temp\ipykernel_4684\364060586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out_expansion_df['Out'] = out_expansion_df.groupby('doc_id')['Out'].transform(lambda x: ''.join(x))
#                                     Title     WikiID  \
# DocID
# 0                       Conus_eugrammatus  894426412
# 1                              JavaScript  664687365
# 2                                     UML  708692214
# 3                     Административен_акт  165924315
# 4      Американска_психологична_асоциация  909584298
#
#                                                      Out
# DocID
# 0      m;meter\n°C;Celsius\nКНР;Китайската народна ре...
# 1      ES6;ECMAScript 6\nHTML;HyperText Markup Langua...
# 2      OMT;Object-modeling technique\nOOSE;Object-Ori...
# 3      ДВ;Държавен вестник\nал.;алинея\nбр.;брой\nт.е...
# 4          САЩ;Съединените Американски Щати\nмлн.;милион

# %% [markdown]
# # Combining In and out expansions in one Dataframe

# %%
doc_titles_series = clean_annotations[['doc_id']].drop_duplicates(ignore_index=True)

# creating the hash keys
doc_titles_series['WikiID'] = doc_titles_series['doc_id'].apply(hash)
doc_titles_series['WikiID'] = doc_titles_series['WikiID'].astype(str).str[1:10]
doc_titles_series

# merge all Inexpansion and Out-expansion df's
expansion_df_final = doc_titles_series.merge(in_expansion_final, how='left', on='WikiID')
expansion_df_final= expansion_df_final.merge(out_expansion_final, how='left', on='WikiID')

# subset and rename columns
expansion_df_final = expansion_df_final[['doc_id', 'WikiID', 'In', 'Out']]
expansion_df_final.rename({'doc_id':'Title'}, inplace=True, axis='columns')

expansion_df_final.head()
# Out:
#                   Title     WikiID  \
# 0     Conus_eugrammatus  894426412
# 1            JavaScript  664687365
# 2                   UML  708692214
# 3   Административен_акт  165924315
# 4  Акционерно_дружество  049006696
#
#                                                   In  \
# 0                                                NaN
# 1                                                NaN
# 2                        OMG;Object Management Group
# 3             АПК;Административнопроцесуалния кодекс
# 4  АД;Акционерно дружество\nЕАД;еднолично акционе...
#
#                                                  Out
# 0  m;meter\n°C;Celsius\nКНР;Китайската народна ре...
# 1  ES6;ECMAScript 6\nHTML;HyperText Markup Langua...
# 2  OMT;Object-modeling technique\nOOSE;Object-Ori...
# 3  ДВ;Държавен вестник\nал.;алинея\nбр.;брой\nт.е...
# 4                                                NaN

# %% [markdown]
# # Add the new 'right' wikiID's

# %%
expansion_df_final['WikiID'] = 0

# set rootdir to the location of the documents in the acx env.
rootdir = 'D:/University/Thesis/annotation_system/acx_annotation/documents/bg/Wikipedia_BG/'


# extract the Doc ID's
def getname(s):    
    nameregex=re.search('id\="(\d+)', s)     # Run search with regex
    
    if nameregex:                                  # If there is a match 
        string_sub = nameregex.group()
        wiki_id = string_sub[4:]
        return wiki_id


# func to get individule documents for the wikipedia data
def wiki_doc_finder(abs_path, list_of_doc):
    """
    
    """
    # creating the document paths
    doc_list = []
    
    for doc in list_of_doc:
        doc_list.append(str(doc + ".txt"))
    
    
    
    # fined the article ID's
    data = {'Title':[], 'WikiID':[]}
    
    for article in doc_list:
        f = open(str(rootdir+article), "r", encoding='utf-8')
        
        text_all = f.read()
        text_sub = text_all[:100]


        data['Title'].append(article[:-4])
        data['WikiID'].append(getname(text_sub))

    return data
                        
id_df = wiki_doc_finder(rootdir, expansion_df_final['Title'])
df = pd.DataFrame.from_dict(id_df)
df

expansion_df_final.drop(axis=1, labels=['WikiID'], inplace=True)
expansion_df_final = expansion_df_final.merge(df, how='left', on='Title')

expansion_df_final = expansion_df_final[['Title', 'WikiID', 'In', 'Out']]
expansion_df_final
# Out:
#                        Title  WikiID  \
# 0          Conus_eugrammatus  564261
# 1                 JavaScript   63292
# 2                        UML  125558
# 3        Административен_акт  104247
# 4       Акционерно_дружество  142761
# ..                       ...     ...
# 97              Христо_Ботев    2919
# 98                      Хълк  376173
# 99                  Хърватия   50904
# 100                      Чип   64785
# 101  Шампионска_лига_на_УЕФА   10709
#
#                                                     In  \
# 0                                                  NaN
# 1                                                  NaN
# 2                          OMG;Object Management Group
# 3               АПК;Административнопроцесуалния кодекс
# 4    АД;Акционерно дружество\nЕАД;еднолично акционе...
# ..                                                 ...
# 97   БРЦК;Българския революционен централен комитет...
# 98                                                 NaN
# 99   ООН;Организацията на обединените нации\nСХС;съ...
# 100                                                NaN
# 101  AG;Aktiengesellschaft\nКЕШ;Купа на европейскит...
#
#                                                    Out
# 0    m;meter\n°C;Celsius\nКНР;Китайската народна ре...
# 1    ES6;ECMAScript 6\nHTML;HyperText Markup Langua...
# 2    OMT;Object-modeling technique\nOOSE;Object-Ori...
# 3    ДВ;Държавен вестник\nал.;алинея\nбр.;брой\nт.е...
# 4                                                  NaN
# ..                                                 ...
# 97                                г.;година\nдр.;други
# 98                                           г.;година
# 99   km;kilometer\nkm2;Square kilometer\nkm²;Square...
# 100               SiO2;Silicon dioxide\nнапр.;например
# 101  ECC;European Champions' Cup\nУЕФА;Съюзът на ев...
#
# [102 rows x 4 columns]

# %%
# document = 'Theorie'
# ID = 42038

# extra_row_1 = {'Title':[document], 'WikiID':[ID], 'In': ['NaN'], 'Out': ['NaN']}

# df_extra_1 = pd.DataFrame(extra_row_1)


# expansion_df_final = pd.concat([expansion_df_final, df_extra_1],  ignore_index=True)
# expansion_df_final
# Out:
#                                                 Title   WikiID  \
# 0                                           Soapserie    13343
# 1                                      Publiek_domein    35876
# 2                                             Bitumen   162682
# 3                             Waterschapsverkiezingen  1642900
# 4                                           Edinburgh    35081
# 5                                 Verenigd_Koninkrijk     1813
# 6                                                SBS6    31688
# 7                                       Koekoeksgraad  4734912
# 8                                                ASML   108617
# 9                                           Radiogolf    54754
# 10                                Memory_of_the_World  2714965
# 11                  Koninklijke_Belgische_Voetbalbond   207787
# 12                                         Wim_Helsen    53313
# 13    Nationale_Maatschappij_der_Belgische_Spoorwegen    15869
# 14                                       BMW_Motorrad   237630
# 15                     Brouwerij_Barbarossa_Groningen   623429
# 16                                         Swiebertje    46439
# 17                                     Rotterdam_Ahoy    73156
# 18                                         Pannenkoek    10755
# 19                      American_Broadcasting_Company   208682
# 20                                          Obligatie     1247
# 21                                 VU_medisch_centrum   195409
# 22                                          Amsterdam  1672534
# 23                                            Chipset    14292
# 24                           Bureau_voor_Normalisatie   271160
# 25                                Belgischer_Rundfunk    23175
# 26                                          Microsoft     1086
# 27                                    Nouvelle_Droite  5216837
# 28                             Bay_Area_Rapid_Transit   940929
# 29                                         Westfalien   286538
# 30            Nederlandse_Voedsel__en_Warenautoriteit   393702
# 31         Organisatie_voor_Islamitische_Samenwerking   776701
# 32                             Signaal_ruisverhouding   203695
# 33       Uitvoeringsinstituut_Werknemersverzekeringen   347815
# 34                         Universiteit_van_Amsterdam    14815
# 35                                 VN_Milieuprogramma  1038320
# 36                                     Visual_effects  5417598
# 37                               Wegingscurves_A_en_C     6301
# 38                                       West_Berlijn   155821
# 39        Wet_op_de_arbeidsongeschiktheidsverzekering    91904
# 40                         Women's_Tennis_Association    12854
# 41                                        Christendom      249
# 42              Massachusetts_Institute_of_Technology    42952
# 43                                           Militair    43760
# 44                                         Neurologie    36026
# 45                                       Dienstplicht    33961
# 46  Wet_medisch_wetenschappelijk_onderzoek_met_mensen  1397021
# 47                                   Orde_van_grootte   858313
# 48                                       TUI_Airlines   455212
# 49                                                BMX     6543
# 50                              De_Nederlandsche_Bank    51127
# 51        Ministerie_van_Economische_Zaken_en_Klimaat  2021968
# 52                                    Röntgenstraling     7332
# 53                                       Koude_Oorlog     6742
# 54                                            Aandeel    26688
# 55                Association_of_Tennis_Professionals    91162
# 56                         Australaziatische_PGA_Tour  2011428
# 57                              Canadian_Space_Agency  1427813
# 58                          Hoge_Raad_der_Nederlanden    11676
# 59                                    Hubbleconstante   381170
# 60  International_Nomenclature_of_Cosmetic_Ingredi...   566696
# 61                              Koninklijke_Landmacht    49891
# 62                                Luchtverkeersleider   161035
# 63             Hoge_commissaris_voor_de_Vluchtelingen    50566
# 64                                             UNESCO    18918
# 65                                               CMYK    10113
# 66                         Fast_moving_consumer_goods   278535
# 67                            Florent_Sinama_Pongolle   861729
# 68                                   Grote_mogendheid   589759
# 69                                      Klein_Duimpje    58655
# 70                                             Laptop    10687
# 71                                            Curaçao    21633
# 72                                    Schatkistpapier   530086
# 73                                           Retorica    40090
# 74                                           Symptoom    69348
# 75                            Comité_Olímpico_Arubano  1841294
# 76                Koninklijke_Luchtvaart_Maatschappij      883
# 77                           Spoorlijn_Boxtel___Wesel   164878
# 78                        Central_Intelligence_Agency    30757
# 79                                            Ecocide  5495640
# 80                                   Centraal_station   152926
# 81                                       Ayrton_Senna    17064
# 82                         E.T._the_Extra_Terrestrial   225165
# 83                    IALA_Maritiem_Betonningsstelsel  1577494
# 84                                  Metro_van_Berlijn    94415
# 85                                                Dvd    10715
# 86                Koninklijke_Nederlandse_Voetbalbond    48272
# 87                                       Platenspeler    16790
# 88                                            Maybach    96959
# 89                                        Bestedingen    64951
# 90                                             Fictie    59023
# 91                                     Langpootmuggen   181981
# 92                                      Suikerfabriek   213202
# 93                                            Theorie    42038
#
#                                                    In  \
# 0   GTST;Goede tijden, slechte tijden\nONM;Onderwe...
# 1      CC0;Creative Commons Publiek Domein Verklaring
# 2      PAK;polycyclische aromatische koolwaterstoffen
# 3   LTO;Land- en Tuinbouworganisatie\nT/m;Tot en m...
# 4                         SNP;Scottish National Party
# 5   EU;Europese Unie\nGB;Groot-Brittannië\nID-kaar...
# 6             SBS6;Scandinavian Broadcasting System 6
# 7                                                 NaN
# 8   ASM;Advanced Semiconductor Materials\nASMI;Adv...
# 9                                  RF;radiofrequentie
# 10  IAC;International Advisory Committee\nIAC-verg...
# 11  BVB;Belgische Voetbalbond\nUBSFA;Union Belge d...
# 12                                                NaN
# 13  DRG;Deutsche Reichsbahn Gesellschaft\nIC;Inter...
# 14  BMW;Bayerische Motoren Werke\nCS;City Scarver\...
# 15                                                NaN
# 16     NCRV;Nederlandse Christelijke Radio Vereniging
# 17                                                NaN
# 18  IHOP;International House of Pancakes\npanza;pa...
# 19                  ABC;American Broadcasting Company
# 20                            OLO;Obligation Linéaire
# 21  AMC;Academisch Medisch Centrum\nAZVU;Academisc...
# 22  ACTA;Academisch Centrum Tandheelkunde Amsterda...
# 23                        PCH;Platform Controller Hub
# 24  BEC;Belgisch Elektrotechnisch Comité\nBIN;Belg...
# 25  BHF;Belgischer Hör- und Fernsehfunk\nBRF;Belgi...
# 26  EC;Europese Commissie\nMS;Microsoft\npc;person...
# 27                                                NaN
# 28  AGT;automated guideway transit\nBART;Bay Area ...
# 29                B;België\nD;Duitsland\nNL;Nederland
# 30  AID;Algemene Inspectiedienst\nEZ;Economische Z...
# 31  OIS;Organisatie voor Islamitische Samenwerking...
# 32  S/n;signaal-ruisverhouding\nSNR;signaal-ruisve...
# 33  BKWI;Bureau Keteninformatisering Werk & Inkome...
# 34  AMOLF;Atoom- en Molecuulfysica\nAUC;Amsterdam ...
# 35  CITES;Convention on the Conservation of Migrat...
# 36  NVX;Nederlandse Vereniging van Visual Effects ...
# 37                                                NaN
# 38                                                NaN
# 39  AAW;Algemene Arbeidsongeschiktheidswet\nCBBS;c...
# 40                     WTA;Women's Tennis Association
# 41                                                NaN
# 42          MIT;Massachusetts Institute of Technology
# 43  Luva;Luchtmacht Vrouwenafdeling\nMarva;Marine ...
# 44                             M.S.;multiple sclerose
# 45     VVDM;Vereniging van Dienstplichtige Militairen
# 46  CCMO;Centrale Commissie Mensgebonden Onderzoek...
# 47  OvG;orde van grootte\ndB;decibel\nnint;nearest...
# 48                                                NaN
# 49                              BMX;Bicycle Motocross
# 50  DNB;De Nederlandsche Bank\nECB;Europese Centra...
# 51  B30;Bezuidenhoutseweg 30\nEZ;Economische Zaken...
# 52  keV;kilo-elektronvolt\nmA;milliampère\npm;pico...
# 53  DDR;Duitse Democratische Republiek\nDVPA;Democ...
# 54  AvA;Algemene vergadering van aandeelhouders\nV...
# 55  ATP;Association of Tennis Professionals\nATP-k...
# 56                                                NaN
# 57  ASC;agence spatiale canadienne\nCSA;Canadian S...
# 58  AG;advocaten-generaal\nHR;Hoge Raad\nPG;procur...
# 59                                                NaN
# 60  INCI;internationale naamgevingssysteem voor co...
# 61  AMOL;Algemene Militaire Opleiding Luchtmobiel\...
# 62                                                NaN
# 63  UNHCR;United Nations High Commissioner for Ref...
# 64  UNESCO;United Nations Educational, Scientific ...
# 65  CMYK;cyan, magenta, yellow, key\nCMY-systeem;c...
# 66  CPG;consumer packaged goods\nFMCG;Fast-moving ...
# 67                                                NaN
# 68              EU;Europese Unie\nVS;Verenigde Staten
# 69                        KHM;Kinder- und Hausmärchen
# 70               desktop-pc;desktop personal computer
# 71  ABC-eilanden;Aruba, Bonaire, Curaçao eilanden\...
# 72                  DTC's;Dutch Treasury Certificates
# 73                                                NaN
# 74                                                NaN
# 75  COA;Comité Olímpico Arubano\nIOC;Internationaa...
# 76  AVOD;Audio Video on Demand\nEBC;Europe Busines...
# 77  NBDS;Noord-Brabantsch-Duitsche Spoorweg-Maatsc...
# 78  CIA;Central Intelligence Agency\nCIG;Central I...
# 79                                                NaN
# 80  CS;centraal station\nHbf;Hauptbahnhof\nhl.n.;h...
# 81                        F1;Formule 1\nGP;Grand Prix
# 82        E.T.;Extra-Terrestrial\nVS;Verenigde Staten
# 83                                                NaN
# 84  BVG;Berliner Verkehrsbetriebe\nGN-Bahn;Gesundb...
# 85  GB;gigabyte\nGiB;gibibyte\nSD;SuperDisc\ncd;co...
# 86  KNVB;Koninklijke Nederlandse Voetbalbond\nNVAB...
# 87  AT;Audio Technica\nMC;moving coil\nMD;magneto-...
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
#
#                                                   Out
# 0   ATWT;As the World Turns\nBNN;Bart's Neverendin...
# 1   CDSM;Copyright in the Digital Single Market\nC...
# 2   v.Chr.;voor Christus\n°C;graden celcius\nTg;gl...
# 3                                                 NaN
# 4   FC;Football Club\nSt;saint\nUNESCO;United Nati...
# 5   BBC;British Broadcasting Corporation\nBSkyB;Br...
# 6   NPO;Nederlandse Publieke Omroep\nRTL;Radio Tél...
# 7                           DNA;Deoxyribonucleic acid
# 8   AEX;Amsterdam Exchange\nAG;Aktiengesellschaft\...
# 9   AF;audio frequency\nAM;Amplitudemodulatie\nELF...
# 10  UNESCO;United Nations Educational, Scientific ...
# 11  ACFF;Association des Clubs Francophones de Foo...
# 12  OLVE;Onze-Lieve-Vrouw-van-Lourdescollege Edege...
# 13  HR-Rail;Human Resource-Rail\nIFB;International...
# 14  ABS;antiblokkeersysteem\nDDR;Duitse Democratis...
# 15              N.V.;Naamloze Vennootschap\nW.;Willem
# 16  NCRV;Nederlandse Christelijke Radio Vereniging...
# 17  ABN;Algemene Bank Nederland\nGGD;Gemeentelijke...
# 18                                                NaN
# 19  CBS;Columbia Broadcasting System\nNBC;National...
# 20  ISIN-code;International Securities Identificat...
# 21  A;Autosnelweg\nBV;Besloten Vennootschap\nIC;In...
# 22  A;Autosnelweg\nAFAS;Applications For Administr...
# 23  AGP;Accelerated Graphics Port\nPCI-E;Periphera...
# 24  CEN;Comité Européen de Normalisation\nEN;Europ...
# 25  ARD;Arbeitsgemeinschaft der öffentlich-rechtli...
# 26  DOS;Dirty Operating System\nAPI;Application Pr...
# 27  GRECE;Groupement de Recherche et d'Études pour...
# 28  ACE;Altamont Corridor Express\nGTW;Gelenktrieb...
# 29  ICS;International Commission on Stratigraphy\n...
# 30  RTL;Radio Télévision Luxembourg\nWob;Wet openb...
# 31                                                NaN
# 32                                                NaN
# 33  CAO;Collectieve Arbeidsovereenkomst\nCGI;Consu...
# 34  ASVA;Algemene Studenten Vereniging Amsterdam\n...
# 35  IUCN;International Union for Conservation of N...
# 36                                                NaN
# 37       Hz;Hertz\ndB;decibel\ndB(A);Decibel A-filter
# 38  DDR;Duitse Democratische Republiek\nS-Bahn-pas...
# 39  CORV;Collectieve Rechtsvordering\nNRC;Nieuwe R...
# 40            ATP;Association of Tennis Professionals
# 41                         NBV;Nieuwe Bijbelvertaling
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  CDA;Christen-Democratisch Appèl\nMilac;Militia...
# 46                                                NaN
# 47                  SI;Système international d'unités
# 48  AOC;Air Operator Certificate\nTUI;Touristik Un...
# 49                                                NaN
# 50  ABN;Algemene Bank Nederland\nAmro;Amsterdamsch...
# 51  D66;Democraten 66\nVVD;Volkspartij voor Vrijhe...
# 52  CT-scans;Computer Tomografie-scans\nDNA;Deoxyr...
# 53  CCP;Chinese Communist Party\nCIA;Central Intel...
# 54  ING;Internationale Nederlanden Groep\nbv-recht...
# 55  ITF;International Tennis Federation\nUS;United...
# 56  AUD;Australische dollar\nPGA;Professional Golf...
# 57  D.C.;District of Columbia\nISS;International S...
# 58  BW;Burgerlijk Wetboek\nJhr;Jonkheer\nPVV;Parti...
# 59  CMB;Cosmic Microwave Background\nMpc;megaparse...
# 60                                                NaN
# 61  CBRN;Chemische, Biologische, Radiologische of ...
# 62   VHF;Very High Frequency\nca.;circa\nkm;kilometer
# 63  UNESCO;United Nations Educational, Scientific ...
# 64                                VN;Verenigde Naties
# 65                            CMY;Cyan Magenta Yellow
# 66                                 e.d.;en dergelijke
# 67  Le Havre AC;Le Havre Athletic Club\nLiverpool ...
# 68  IMF;Internationaal Monetair Fonds\nUSSR;Union ...
# 69                              v. Chr.;voor Christus
# 70  ca;circa\ndesktop-pc;desktop personal computer...
# 71  BNP;Bruto Nationaal Product\nCBS;Centraal Bure...
# 72                                                NaN
# 73                               v.Chr.;voor Christus
# 74             SARS;Severe Acute Respiratory Syndrome
# 75                                                NaN
# 76  BOAC;British Overseas Airways Corporation\nNLM...
# 77  BBA;Brabantsche Buurtspoorwegen en Autodienste...
# 78  BND;Bundesnachrichtendienst\nBVD;Binnenlandse ...
# 79  Art.;Artikel\nEU;Europese Unie\nArt;Artikel\nE...
# 80  HSL;hogesnelheidslijn\nHSL-Noord;Hogesnelheids...
# 81  HANS;Head and Neck Support system\nF3;Formule ...
# 82  MCA;Music Corporation of America\nUSC;Universi...
# 83  IALA;International Association of Lighthouse A...
# 84  AEG;Allgemeine Elektricitäts-Gesellschaft\nDDR...
# 85  EFM;Eight-to-Fourteen Modulation\nIBM;Internat...
# 86  FIFA;Fédération Internationale de Football Ass...
# 87  EMT;Elektro-Mess-Technik\nJVC;Japan Victor Com...
# 88  GmbH;Gesellschaft mit beschränkter Haftung\nIA...
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN

# %% [markdown]
# # Saving all requiered files for the system

# %%
mapWikiIds = expansion_df_final[['WikiID']]
mapWikiIds.to_csv('D:/University/Thesis/acx/acrodisam_app/data/UsersWikipediaBG/mapWikiIds.txt',
                 index_label=False,
                 header=False)

# %%
expansion_df_final.to_csv('D:/University/Thesis/acx/acrodisam_app/data/UsersWikipediaBG/complete_user_annotations.csv',
                         index_label='DocID')

# %%
# acx_wiki = pd.read_csv('/Users/jesher/Desktop/Master data science UvA/Semester 2/Thesis/acx_104_pycharm/data/UsersWikipedia_en/complete_user_annotations.csv',
#                       index_col='DocID')

# %%
pd.set_option('display.max_rows', None)
len(expansion_df_final)
# Out:
# 102

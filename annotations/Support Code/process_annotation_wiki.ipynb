# %% [markdown]
# # User annotation pre-processing script
#
# This script can be used to manualy clean the user annotations for the AcX system.
#
# ### Preparation:
#  - Use google-cloud-sdk to download the annotations in .json format
#  - Add the .json files to single folder (I called it 'google_annotation/json_data/', but you can of course change the name and code
#  - When it is the first time you clean the data, commend the following lines:
#      - clean_annotations = pd.read_csv('./clean_data/clean_annotations_nl.csv')
#      - already_clean_docs = set(clean_annotations['doc_id'])
#      - !! ALSO, REMOVE "already_clean_docs" from dirty_docs = total_docs - already_clean_docs !!
#      - undo all of this once you've cleaned up the first documents and have a clean_annotations_XX.csv file.
#
# ### Cleaning the documents:
# * [Difference Finder](#Difference-Finder): The code in these cells checks the differences between the annotators of the same document. There are two common differences:
#      1. One annotator missed an acronym
#      2. The annotators wrote the acronym or expansion in two different ways.
# A document gets returned if one or both of these differences occurs.
#
# * [Manual cleaning](#Manual-cleaning)
# Cleaning the documents is done using the pandas' framework. Please follow the following steps:
#     1. Enter the document of intrest --> document = '....'
#     2. Check the output of differences and add the row numbers in the cell below (row_num_1 & row_num_2)
#     3. Use the next cell to change the values inside the data frame. You can change values by using the .iloc[.., ..] statement or add a row with the extra_row variable in combination with the append statement.
#     4. All the acronyms and expansions for the document of interest are printed below for one last check.
#     5. [Saving changes](#Saving-changes) Finally, You can append and save the output to the clean_annotations_xx.csv. I would recommend doing this after every document.
#
# ### Some other issues you might encounter
# - Mail issue: The document IDs were generated by splitting the names of the .json files based on a _ . However, some emails use an underscore, which will create improper document splits. This issue is solved by explicitly splitting on the name. Therefore, add all email addresses with an underscore to the "exception_mails" list.
# - Documents with only one annotator: Some documents will not yet be annotated by two people. You can ignore these documents for now.

# %%
"""
Script for processing and cleaning the google drive annotations.
The output is a .csv file with the acronyms and expansions per document.
Date: 23-05-2022
"""
# Out:
# '\nScript for processing and cleaning the google drive annotations.\nThe output is a .csv file with the acronyms and expansions per document.\nDate: 23-05-2022\n'

# %%
import os
import pandas as pd
import re

# %% [markdown]
# ## Loading the Annotations

# %%
rootdir = 'D:/University/Thesis/annotations/annotations'
df = pd.DataFrame(columns=['acronym', 'expansion', 'language', 'type'])

# Loading the clean annotations (Only you run this if you have clean annotations already)
# raw_annotations = cleaning_raw_annotation(df, rootdir)

# %%
def cleaning_raw_annotation(df, rootdir):
    # Creating the file directories
    for subdir, dirs, files in os.walk(rootdir):
        for file in files:
            abs_path = os.path.join(subdir, file)
            individual_json = pd.read_json(abs_path, encoding="utf-8")

            # Extracting the annotators
            exception_mails = ['contact@iliyasgeorgiev.com']

            # filer for mails with an underscore
            for i in exception_mails:
                if bool(re.search(i, abs_path.split('/')[-1])):
                    annotators = i
                else:
                    annotators = abs_path.split('_')[-1]
                    annotators = annotators[:-5]

            # Extracting the document ID's
            doc_id = abs_path.split('\\')[-1]
            doc_id = doc_id.replace(annotators, '')[:-6]

            # Transforming the json  in a proper format
            individual_json = individual_json.transpose()
            individual_json.reset_index(inplace=True)
            individual_json = individual_json.rename(columns={'index':'acronym'})
            individual_json['doc_id'] = doc_id
            individual_json['annotator'] = annotators

            # adding everything together in a df
            df = pd.concat([df, individual_json], ignore_index=True)

            # fill the missing values in the language column
            df['language'].replace('', "other language", inplace=True)
            
            # remove additional white spaces
            df['acronym'] = df['acronym'].str.strip()
            df['expansion'] = df['expansion'].str.strip()

    return df

# %%
# Run this cell only at the beginning !!!!!!! All clean annotations will be lost if executed 
annotation_df = cleaning_raw_annotation(df, rootdir)
# annotation_df = clean_annotations

# annotation_df

# %%
# Corpus info
print('Number of annotators: {}'.format(len(set(annotation_df['annotator']))))
print('Number of documents: {}'.format(len(set(annotation_df['doc_id']))))
print('Number of clean documents: {}'.format(len(set(annotation_df['doc_id']))))
# Out:
# Number of annotators: 8
# Number of documents: 102
# Number of clean documents: 102

# %% [markdown]
# ## Difference Finder <a class="anchor" id="Difference-Finder"></a>
# The following code section looks for the differences between the annotated documents

# %%
#
total_docs =set(annotation_df['doc_id'])
already_clean_docs = set(clean_annotations['doc_id'])
print(len(already_clean_docs))
print('Number of documents that need to be cleaned: {}'.format(len(total_docs.difference(already_clean_docs))))
# dirty document info
dirty_docs = total_docs - already_clean_docs
print("Number of dirty documents:{}".format(len(dirty_docs)))


# Return all doc_id's with an uneven number of acroyms (which means...)
print("\nDOCUMENTS WITH AN UNEVEN NUMBER OF ACRONYMS:")
dirt_1 = []
for i in set(annotation_df['doc_id']):
    if i in dirty_docs:
        if len(annotation_df[annotation_df['doc_id'] == str(i)]) % 2 != 0:
            dirt_1.append(i)
            print("  -", i)
        
print("\nDOCUMENTS WITH DUPLICATE ROWS:")
dirt_2 = []
for i in set(annotation_df['doc_id']):
    sub_set_df = annotation_df[annotation_df['doc_id'] == i]
    if i in dirty_docs:
    # Delete duplicate rows
        if len(sub_set_df.drop_duplicates(subset=["acronym", "expansion"], keep=False)) != 0:
            dirt_2.append(i)
            print("  -", i)

del sub_set_df
# Out:
# 102
# Number of documents that need to be cleaned: 0
# Number of dirty documents:0
#
# DOCUMENTS WITH AN UNEVEN NUMBER OF ACRONYMS:
#
# DOCUMENTS WITH DUPLICATE ROWS:

# %%
import csv

docs = {}
for i in annotation_df.iterrows():
    annotation = i[1]
    if i[1].doc_id not in docs:
        docs[i[1].doc_id] = {}
    if i[1].annotator not in docs[i[1].doc_id]:
        docs[i[1].doc_id][i[1].annotator] = {}
    if i[1].type not in docs[i[1].doc_id][i[1].annotator]:
        docs[i[1].doc_id][i[1].annotator][i[1].type] = []
        docs[i[1].doc_id][i[1].annotator][i[1].type].append({i[1].acronym:i[1].expansion})
        # docs[i[1].doc_id][i[1].annotator] = [i[1].acronym, i[1].expansion, i[1].language, i[1].type, i[1].annotator]
    else:    
        docs[i[1].doc_id][i[1].annotator][i[1].type].append({i[1].acronym:i[1].expansion})
        # docs[i[1].doc_id][i[1].annotator] = docs[i[1].doc_id][i[1].annotator] + [i[1].acronym, i[1].expansion, i[1].language, i[1].type, i[1].annotator]
# get type of docs

# print (list(docs)[1])
# print (docs['JavaScript'])
# create csv file with the annotations
with open('test_annotations.csv', 'w', newline='') as csvfile:
    fieldnames = ['DocID', 'Title', 'WikiID', 'U1 in', 'U1 Out', 'U2 in', 'U2 out']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    counter = 1
    for doc in docs:
        row = {}
        row['DocID'] = counter
        row['Title'] = doc.replace('_', ' ')
        for annotator in docs[doc]:
            print (annotator)
            print (docs[doc][annotator])
            if 'in_expansion' in docs[doc][annotator]:
                print (docs[doc][annotator]['in_expansion'])
            if 'out_expansion' in docs[doc][annotator]:
                print (docs[doc][annotator]['out_expansion'])
            #write cvs 
# for doc in docs.items():
#     print (list(doc[1].items())[0][0])
    # if(len(list(doc[1].items())[0][1]['out_expansion']) == 0):
    #     print('No out_expansion')
    # else:
    #     print (list(doc[1].items())[0][1]['out_expansion'])
    # if 'in_expansion' in list(doc[1].items())[0][1]:
    #     print('No in_expansion')
    # else:
    #     print (list(doc[1].items())[0][1]['in_expansion'])
# Out:
# Conus_eugrammatus
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'m': 'meter'}, {'°C': 'Celsius'}, {'КНР': 'Китайската народна република'}, {'САЩ': 'Съединени Американски Щати'}]}
# [{'m': 'meter'}, {'°C': 'Celsius'}, {'КНР': 'Китайската народна република'}, {'САЩ': 'Съединени Американски Щати'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'m': 'meter'}, {'°C': 'Celsius'}, {'КНР': 'Китайската народна република'}, {'САЩ': 'Съединени Американски Щати'}]}
# [{'m': 'meter'}, {'°C': 'Celsius'}, {'КНР': 'Китайската народна република'}, {'САЩ': 'Съединени Американски Щати'}]
# JavaScript
# contact@iliyasgeorgiev.com
# {'out_expansion': [{'ES6': 'ECMAScript 6'}, {'HTML': 'HyperText Markup Language'}, {'JSON': 'JavaScript Object Notation'}, {'САЩ': 'Съединени американски щати'}, {'г.': 'година'}, {'т.е.': 'тоест'}]}
# [{'ES6': 'ECMAScript 6'}, {'HTML': 'HyperText Markup Language'}, {'JSON': 'JavaScript Object Notation'}, {'САЩ': 'Съединени американски щати'}, {'г.': 'година'}, {'т.е.': 'тоест'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'ES6': 'ECMAScript 6'}, {'HTML': 'HyperText Markup Language'}, {'JSON': 'JavaScript Object Notation'}, {'VBScript': 'Microsoft Visual Basic Scripting Edition'}, {'г.': 'Година'}]}
# [{'ES6': 'ECMAScript 6'}, {'HTML': 'HyperText Markup Language'}, {'JSON': 'JavaScript Object Notation'}, {'VBScript': 'Microsoft Visual Basic Scripting Edition'}, {'г.': 'Година'}]
# UML
# contact@iliyasgeorgiev.com
# {'in_expansion': [{'OMG': 'Object Management Group'}], 'out_expansion': [{'OMT': 'Object Modeling Technique'}, {'OOSE': 'Object-Oriented Software Engineering'}, {'UML': 'Unified Modeling Language'}, {'ИТ': 'Информационни технологии'}]}
# [{'OMG': 'Object Management Group'}]
# [{'OMT': 'Object Modeling Technique'}, {'OOSE': 'Object-Oriented Software Engineering'}, {'UML': 'Unified Modeling Language'}, {'ИТ': 'Информационни технологии'}]
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'IBM': 'International Business Machines Corporation'}, {'OMT': 'Object-modeling technique'}, {'OOSE': 'object-oriented software engineering'}, {'UML': 'Unified Modeling Language'}, {'ИТ': 'Информационните технологии'}], 'in_expansion': [{'OMG': 'Object Management Group'}]}
# [{'OMG': 'Object Management Group'}]
# [{'IBM': 'International Business Machines Corporation'}, {'OMT': 'Object-modeling technique'}, {'OOSE': 'object-oriented software engineering'}, {'UML': 'Unified Modeling Language'}, {'ИТ': 'Информационните технологии'}]
# Административен_акт
# g.yordanov999@gmail.com
# {'in_expansion': [{'АПК': 'Административнопроцесуалния кодекс'}], 'out_expansion': [{'ДВ': 'Държавен вестник'}, {'ал.': 'алинея'}, {'бр.': 'брой'}, {'т.е.': 'тоест'}, {'чл.': 'член'}]}
# [{'АПК': 'Административнопроцесуалния кодекс'}]
# [{'ДВ': 'Държавен вестник'}, {'ал.': 'алинея'}, {'бр.': 'брой'}, {'т.е.': 'тоест'}, {'чл.': 'член'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'АПК': 'Административнопроцесуалния кодекс'}], 'out_expansion': [{'ДВ': 'Държавен вестник'}, {'ал.': 'алинея'}, {'бр.': 'брой'}, {'т.е.': 'тоест'}, {'чл.': 'член'}]}
# [{'АПК': 'Административнопроцесуалния кодекс'}]
# [{'ДВ': 'Държавен вестник'}, {'ал.': 'алинея'}, {'бр.': 'брой'}, {'т.е.': 'тоест'}, {'чл.': 'член'}]
# Акционерно_дружество
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'АД': 'Акционерно дружество'}, {'ЕАД': 'еднолично акционерно дружество'}]}
# [{'АД': 'Акционерно дружество'}, {'ЕАД': 'еднолично акционерно дружество'}]
# stella.vouteva@gmail.com
# {'in_expansion': [{'АД': 'Акционерно дружество'}, {'ЕАД': 'еднолично акционерно дружество'}]}
# [{'АД': 'Акционерно дружество'}, {'ЕАД': 'еднолично акционерно дружество'}]
# Американска_психологична_асоциация
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'АПА': 'Американската психологична асоциация'}], 'out_expansion': [{'САЩ': 'Съединените Американски Щати'}, {'млн.': 'милион'}]}
# [{'АПА': 'Американската психологична асоциация'}]
# [{'САЩ': 'Съединените Американски Щати'}, {'млн.': 'милион'}]
# georgitidorov4508@gmail.com
# {'in_expansion': [{'АПА': 'Американската психологична асоциация'}], 'out_expansion': [{'млн.': 'милион'}]}
# [{'АПА': 'Американската психологична асоциация'}]
# [{'млн.': 'милион'}]
# Амстердамски_университет
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'ВУЗ': 'Ввисше учебно заведени'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]}
# [{'ВУЗ': 'Ввисше учебно заведени'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'ВУЗ': 'Висше учебно заведение'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]}
# [{'ВУЗ': 'Висше учебно заведение'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]
# Банкова_консолидационна_компания
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'БКК': 'Банковата консолидационна компания'}], 'out_expansion': [{'ДПС': 'Движение за права и свободи'}, {'ДСК': 'Държавна спестовна каса'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'г.': 'година'}, {'гр.': 'град'}, {'млрд.': 'милиярд'}, {'п.к.': 'пощенски код'}, {'ул.': 'улица'}]}
# [{'БКК': 'Банковата консолидационна компания'}]
# [{'ДПС': 'Движение за права и свободи'}, {'ДСК': 'Държавна спестовна каса'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'г.': 'година'}, {'гр.': 'град'}, {'млрд.': 'милиярд'}, {'п.к.': 'пощенски код'}, {'ул.': 'улица'}]
# stella.vouteva@gmail.com
# {'in_expansion': [{'БКК': 'Банковата консолидационна компания'}], 'out_expansion': [{'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'г.': 'година'}, {'гр.': 'град'}, {'п.к.': 'Пощенски код'}, {'ул.': 'Улица'}]}
# [{'БКК': 'Банковата консолидационна компания'}]
# [{'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'г.': 'година'}, {'гр.': 'град'}, {'п.к.': 'Пощенски код'}, {'ул.': 'Улица'}]
# Баркод
# g.yordanov999@gmail.com
# {'out_expansion': [{'2D': 'two dimensional'}, {'ISBN': 'International Standard Book Number'}, {'ISSN': 'International Standard Serial Number'}, {'ITF': 'Interleaved Two of Five'}, {'QR': 'quick response code'}, {'US': 'United States'}, {'ЕАН': 'Европейски номер на артикула'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'EAN': 'European Article Numbering'}, {'UCC': 'Uniform Code Council'}, {'UPC': 'Universal Product Code'}, {'БТПП': 'Българска търговско-промишлена палата'}]}
# [{'EAN': 'European Article Numbering'}, {'UCC': 'Uniform Code Council'}, {'UPC': 'Universal Product Code'}, {'БТПП': 'Българска търговско-промишлена палата'}]
# [{'2D': 'two dimensional'}, {'ISBN': 'International Standard Book Number'}, {'ISSN': 'International Standard Serial Number'}, {'ITF': 'Interleaved Two of Five'}, {'QR': 'quick response code'}, {'US': 'United States'}, {'ЕАН': 'Европейски номер на артикула'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'2D': 'two dimensional'}, {'ISBN': 'International Standard Book Number'}, {'ISSN': 'International Standard Serial Number'}, {'ITF': 'Interleaved Two of Five'}, {'QR': 'quick response code'}, {'US': 'United States'}, {'ЕАН': 'Европейски номер на артикула'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'EAN': 'European Article Numbering'}, {'UCC': 'Uniform Code Council'}, {'UPC': 'Universal Product Code'}, {'БТПП': 'Българска търговско-промишлена палата'}]}
# [{'EAN': 'European Article Numbering'}, {'UCC': 'Uniform Code Council'}, {'UPC': 'Universal Product Code'}, {'БТПП': 'Българска търговско-промишлена палата'}]
# [{'2D': 'two dimensional'}, {'ISBN': 'International Standard Book Number'}, {'ISSN': 'International Standard Serial Number'}, {'ITF': 'Interleaved Two of Five'}, {'QR': 'quick response code'}, {'US': 'United States'}, {'ЕАН': 'Европейски номер на артикула'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}]
# Берлин
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'WTA': "Women's Tennis Association"}, {'km': 'kilometer'}, {'km²': 'Square kilometer'}, {'m': 'meter'}, {'°C': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ВУЗ': 'Висше учебно заведени'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'СК': 'спортен клуб'}, {'СССР': 'Съюз на съветските социалистически републики'}, {'ФК': 'Футболен клуб'}, {'ЮНЕСКО': 'Организация на Обединените нации по въпросите на образованието, науката и културата'}, {'г.': 'година'}, {'млрд.': 'милиард'}, {'пр.н.е.': 'преди новата ера'}], 'in_expansion': [{'ЕС': 'Европейския съюз'}]}
# [{'ЕС': 'Европейския съюз'}]
# [{'WTA': "Women's Tennis Association"}, {'km': 'kilometer'}, {'km²': 'Square kilometer'}, {'m': 'meter'}, {'°C': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ВУЗ': 'Висше учебно заведени'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'СК': 'спортен клуб'}, {'СССР': 'Съюз на съветските социалистически републики'}, {'ФК': 'Футболен клуб'}, {'ЮНЕСКО': 'Организация на Обединените нации по въпросите на образованието, науката и културата'}, {'г.': 'година'}, {'млрд.': 'милиард'}, {'пр.н.е.': 'преди новата ера'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'WTA': "Women's Tennis Association"}, {'km': 'kilometer'}, {'km²': 'Square kilometer'}, {'m': 'meter'}, {'°C': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ВУЗ': 'Висше учебно заведени'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'СК': 'спортен клуб'}, {'СССР': 'Съюз на съветските социалистически републики'}, {'ФК': 'Футболен клуб'}, {'ЮНЕСКО': 'Организация на Обединените нации по въпросите на образованието, науката и културата'}, {'г.': 'година'}, {'млрд.': 'милиард'}, {'пр.н.е.': 'преди новата ера'}], 'in_expansion': [{'ЕС': 'Европейския съюз'}]}
# [{'ЕС': 'Европейския съюз'}]
# [{'WTA': "Women's Tennis Association"}, {'km': 'kilometer'}, {'km²': 'Square kilometer'}, {'m': 'meter'}, {'°C': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ВУЗ': 'Висше учебно заведени'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'СК': 'спортен клуб'}, {'СССР': 'Съюз на съветските социалистически републики'}, {'ФК': 'Футболен клуб'}, {'ЮНЕСКО': 'Организация на Обединените нации по въпросите на образованието, науката и културата'}, {'г.': 'година'}, {'млрд.': 'милиард'}, {'пр.н.е.': 'преди новата ера'}]
# Би_Би_Си
# georgitidorov4508@gmail.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'БАН': 'Българска академия на науките'}, {'акад.': 'академик'}, {'г.': 'година'}, {'др.': 'други'}]}
# [{'BBC': 'British Broadcasting Corporation'}, {'БАН': 'Българска академия на науките'}, {'акад.': 'академик'}, {'г.': 'година'}, {'др.': 'други'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'БАН': 'Българска академия на науките'}, {'г.': 'година'}]}
# [{'BBC': 'British Broadcasting Corporation'}, {'БАН': 'Българска академия на науките'}, {'г.': 'година'}]
# Би_Ти_Ви
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'HD': 'High Definition'}, {'IPTV': 'Internet Protocol television'}, {'MUX': 'Multiplexer'}, {'SD': 'Standard definition'}, {'АД': 'Акционерно дружество'}, {'ЕАД': 'Еднолично акционерно дружество'}, {'МС': 'Министерски съвет'}, {'НДК': 'Национален дворец на културата'}, {'ООД': 'Дружество с ограничена отговорност'}, {'ПТС': 'Подвижна телевизионна станция'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}], 'in_expansion': [{'ДКД': 'Държавната комисия по далекосъобщения'}, {'КРС': 'Комисия по регулиране на съобщенията'}, {'СЕМ': 'Съветът за електронни медии'}, {'СМЕ': 'Central European Media Enterprises'}]}
# [{'ДКД': 'Държавната комисия по далекосъобщения'}, {'КРС': 'Комисия по регулиране на съобщенията'}, {'СЕМ': 'Съветът за електронни медии'}, {'СМЕ': 'Central European Media Enterprises'}]
# [{'BBC': 'British Broadcasting Corporation'}, {'HD': 'High Definition'}, {'IPTV': 'Internet Protocol television'}, {'MUX': 'Multiplexer'}, {'SD': 'Standard definition'}, {'АД': 'Акционерно дружество'}, {'ЕАД': 'Еднолично акционерно дружество'}, {'МС': 'Министерски съвет'}, {'НДК': 'Национален дворец на културата'}, {'ООД': 'Дружество с ограничена отговорност'}, {'ПТС': 'Подвижна телевизионна станция'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'HD': 'High Definition'}, {'IPTV': 'Internet Protocol television'}, {'MUX': 'Multiplexer'}, {'SD': 'Standard definition'}, {'АД': 'Акционерно дружество'}, {'ЕАД': 'Еднолично акционерно дружество'}, {'МС': 'Министерски съвет'}, {'НДК': 'Национален дворец на културата'}, {'ООД': 'Дружество с ограничена отговорност'}, {'ПТС': 'Подвижна телевизионна станция'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}], 'in_expansion': [{'ДКД': 'Държавната комисия по далекосъобщения'}, {'КРС': 'Комисия по регулиране на съобщенията'}, {'СЕМ': 'Съветът за електронни медии'}, {'СМЕ': 'Central European Media Enterprises'}]}
# [{'ДКД': 'Държавната комисия по далекосъобщения'}, {'КРС': 'Комисия по регулиране на съобщенията'}, {'СЕМ': 'Съветът за електронни медии'}, {'СМЕ': 'Central European Media Enterprises'}]
# [{'BBC': 'British Broadcasting Corporation'}, {'HD': 'High Definition'}, {'IPTV': 'Internet Protocol television'}, {'MUX': 'Multiplexer'}, {'SD': 'Standard definition'}, {'АД': 'Акционерно дружество'}, {'ЕАД': 'Еднолично акционерно дружество'}, {'МС': 'Министерски съвет'}, {'НДК': 'Национален дворец на културата'}, {'ООД': 'Дружество с ограничена отговорност'}, {'ПТС': 'Подвижна телевизионна станция'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}]
# БНТ_1
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'DVB-T': 'Digital Video Broadcasting - Terrestrial'}, {'HD': 'High Definition'}, {'БНТ': 'Българската национална телевизия'}, {'г.': 'година'}]}
# [{'DVB-T': 'Digital Video Broadcasting - Terrestrial'}, {'HD': 'High Definition'}, {'БНТ': 'Българската национална телевизия'}, {'г.': 'година'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'DVB-T': 'Digital Video Broadcasting - Terrestrial'}, {'HD': 'High Definition'}, {'БНТ': 'Българската национална телевизия'}, {'г.': 'година'}]}
# [{'DVB-T': 'Digital Video Broadcasting - Terrestrial'}, {'HD': 'High Definition'}, {'БНТ': 'Българската национална телевизия'}, {'г.': 'година'}]
# БНТ_2
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'БНТ': 'Българската национална телевизия'}], 'out_expansion': [{'РТВЦ': 'Регионален телевизионен център'}, {'г.': 'година'}, {'ч.': 'часа'}]}
# [{'БНТ': 'Българската национална телевизия'}]
# [{'РТВЦ': 'Регионален телевизионен център'}, {'г.': 'година'}, {'ч.': 'часа'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'БНТ': 'Българската национална телевизия'}], 'out_expansion': [{'РТВЦ': 'Регионален телевизионен център'}, {'г.': 'година'}, {'ч.': 'часа'}]}
# [{'БНТ': 'Българската национална телевизия'}]
# [{'РТВЦ': 'Регионален телевизионен център'}, {'г.': 'година'}, {'ч.': 'часа'}]
# Бобслей
# contact@iliyasgeorgiev.com
# {'out_expansion': [{'kg': 'kilogram'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограм'}]}
# [{'kg': 'kilogram'}, {'ГДР': 'Германска демократична република'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограм'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'FIBT': 'Fédération internationale de bobsleigh et de tobogganing'}], 'out_expansion': [{'kg': 'kilogram'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограм'}, {'кг.': 'килограм'}]}
# [{'FIBT': 'Fédération internationale de bobsleigh et de tobogganing'}]
# [{'kg': 'kilogram'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограм'}, {'кг.': 'килограм'}]
# Ботаника
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'др.': 'други'}]}
# [{'др.': 'други'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'ДНК': 'Дезоксирибонуклеинова киселина'}]}
# [{'ДНК': 'Дезоксирибонуклеинова киселина'}]
# Българска_народна_банка
# stella.vouteva@gmail.com
# {'out_expansion': [{'БКП': 'Българска Комунистическа Партия'}, {'ДЦК': 'Държавни Ценни Книжа'}, {'ЛЕОНИА Плюс': 'LEv OverNight Index Average Plus'}, {'ОЛП': 'Основен лихвен процент'}, {'бр.': 'брой'}, {'г.': 'година'}, {'чл.': 'член'}], 'in_expansion': [{'БНБ': 'Българската народна банка'}]}
# [{'БНБ': 'Българската народна банка'}]
# [{'БКП': 'Българска Комунистическа Партия'}, {'ДЦК': 'Държавни Ценни Книжа'}, {'ЛЕОНИА Плюс': 'LEv OverNight Index Average Plus'}, {'ОЛП': 'Основен лихвен процент'}, {'бр.': 'брой'}, {'г.': 'година'}, {'чл.': 'член'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'БКП': 'Българска комунистическа партия'}, {'ЛЕОНИА Плюс': 'LEv OverNight Index Average Plus'}, {'ОЛП': 'Основен лихвен процент'}, {'бр.': 'брой'}, {'г.': 'година'}, {'чл.': 'член'}], 'in_expansion': [{'БНБ': 'Българската народна банка'}]}
# [{'БНБ': 'Българската народна банка'}]
# [{'БКП': 'Българска комунистическа партия'}, {'ЛЕОНИА Плюс': 'LEv OverNight Index Average Plus'}, {'ОЛП': 'Основен лихвен процент'}, {'бр.': 'брой'}, {'г.': 'година'}, {'чл.': 'член'}]
# Българска_социалистическа_партия
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българската комунистическа партия'}, {'ВС': 'Върховен съд'}, {'ГЕРБ': 'Граждани за европейско развитие на България'}, {'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'ОДС': 'Обединени демократични сили'}, {'ОНС': 'Общински народен съвет'}, {'ПК': 'Политически клуб'}, {'СДС': 'Съюз на демократичните сили'}, {'г.': 'година'}], 'in_expansion': [{'БСП': 'Българската социалистическа партия'}, {'ПЕС': 'Платформа Европейски социалисти'}]}
# [{'БСП': 'Българската социалистическа партия'}, {'ПЕС': 'Платформа Европейски социалисти'}]
# [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българската комунистическа партия'}, {'ВС': 'Върховен съд'}, {'ГЕРБ': 'Граждани за европейско развитие на България'}, {'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'ОДС': 'Обединени демократични сили'}, {'ОНС': 'Общински народен съвет'}, {'ПК': 'Политически клуб'}, {'СДС': 'Съюз на демократичните сили'}, {'г.': 'година'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'БЗНС': 'Български земеделски народен съюз'}, {'БСДП': 'Българската социалдемократическа партия'}, {'ВС': 'Върховен съд'}, {'ГЕРБ': 'Граждани за европейско развитие на България'}, {'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'ОДС': 'Обединен демократичен съюз'}, {'ОНС': 'Обикновено народно събрание'}, {'ПК Екогласност': 'Политически клуб Екогласност'}, {'СДС': 'Съюз на демократичните сили'}, {'г.': 'година'}, {'ген.': 'генерал'}], 'in_expansion': [{'БКП': 'Българската комунистическа партия'}, {'БСП': 'Българската социалистическа партия'}, {'ПЕС': 'Платформа Европейски социалисти'}]}
# [{'БКП': 'Българската комунистическа партия'}, {'БСП': 'Българската социалистическа партия'}, {'ПЕС': 'Платформа Европейски социалисти'}]
# [{'БЗНС': 'Български земеделски народен съюз'}, {'БСДП': 'Българската социалдемократическа партия'}, {'ВС': 'Върховен съд'}, {'ГЕРБ': 'Граждани за европейско развитие на България'}, {'ДПС': 'Движение за права и свободи'}, {'НДСВ': 'Национално движение за стабилност и възход'}, {'ОДС': 'Обединен демократичен съюз'}, {'ОНС': 'Обикновено народно събрание'}, {'ПК Екогласност': 'Политически клуб Екогласност'}, {'СДС': 'Съюз на демократичните сили'}, {'г.': 'година'}, {'ген.': 'генерал'}]
# Васил_Левски
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'БРЦК': 'Българския революционен централен комитет'}, {'ВРО': 'Вътрешната революционна организация'}], 'out_expansion': [{'ал.': 'алинея'}, {'г.': 'година'}, {'гр.': 'град'}, {'др.': 'други'}, {'проф.': 'професор'}, {'с.': 'страница'}, {'чл.': 'член'}]}
# [{'БРЦК': 'Българския революционен централен комитет'}, {'ВРО': 'Вътрешната революционна организация'}]
# [{'ал.': 'алинея'}, {'г.': 'година'}, {'гр.': 'град'}, {'др.': 'други'}, {'проф.': 'професор'}, {'с.': 'страница'}, {'чл.': 'член'}]
# stella.vouteva@gmail.com
# {'in_expansion': [{'БРЦК': 'Българския революционен централен комитет'}, {'ВРО': 'Вътрешната революционна организация'}], 'out_expansion': [{'ал.': 'алинея'}, {'г.': 'година'}, {'гр.': 'град'}, {'др.': 'други'}, {'отд.': 'отделение'}, {'проф.': 'професор'}, {'с.': 'село'}, {'чл.': 'член'}]}
# [{'БРЦК': 'Българския революционен централен комитет'}, {'ВРО': 'Вътрешната революционна организация'}]
# [{'ал.': 'алинея'}, {'г.': 'година'}, {'гр.': 'град'}, {'др.': 'други'}, {'отд.': 'отделение'}, {'проф.': 'професор'}, {'с.': 'село'}, {'чл.': 'член'}]
# Водноелектрическа_централа
# g.yordanov999@gmail.com
# {'out_expansion': [{'kW': 'Kilowatt'}, {'МW': 'Megawatt'}, {'кг': 'килограма'}, {'куб.': 'кубичен'}], 'in_expansion': [{'ВЕЦ': 'Водноелектрическа централа'}, {'НВРВН': 'най-високо работно водно ниво'}]}
# [{'ВЕЦ': 'Водноелектрическа централа'}, {'НВРВН': 'най-високо работно водно ниво'}]
# [{'kW': 'Kilowatt'}, {'МW': 'Megawatt'}, {'кг': 'килограма'}, {'куб.': 'кубичен'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'kW': 'Kilowatt'}, {'МW': 'Megawatt'}, {'кг': 'килограма'}, {'куб.': 'кубичен'}], 'in_expansion': [{'ВЕЦ': 'Водноелектрическа централа'}, {'НВРВН': 'най-високо работно водно ниво'}]}
# [{'ВЕЦ': 'Водноелектрическа централа'}, {'НВРВН': 'най-високо работно водно ниво'}]
# [{'kW': 'Kilowatt'}, {'МW': 'Megawatt'}, {'кг': 'килограма'}, {'куб.': 'кубичен'}]
# Волейбол
# stella.vouteva@gmail.com
# {'in_expansion': [{'CEV': 'Европейската конфедерация по волейбол'}, {'FIVB': 'Международната федерация по волейбол'}, {'БНСФ': 'Българска национална спортна федерация'}, {'КИРВ': 'Комитет за игрите с ръчна топка'}, {'МОК': 'Международния олимпийски комитет'}, {'РСВ': 'Републиканска секция по волейбол'}, {'САЩ': 'Съединени Американски Щати'}, {'СИРТ': 'Съюз за игрите с ръчна топка'}], 'out_expansion': [{'ФИВБ': 'Международната федерация по волейбол'}, {'т. нар.': 'Така наречен'}]}
# [{'CEV': 'Европейската конфедерация по волейбол'}, {'FIVB': 'Международната федерация по волейбол'}, {'БНСФ': 'Българска национална спортна федерация'}, {'КИРВ': 'Комитет за игрите с ръчна топка'}, {'МОК': 'Международния олимпийски комитет'}, {'РСВ': 'Републиканска секция по волейбол'}, {'САЩ': 'Съединени Американски Щати'}, {'СИРТ': 'Съюз за игрите с ръчна топка'}]
# [{'ФИВБ': 'Международната федерация по волейбол'}, {'т. нар.': 'Така наречен'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'CEV': 'Европейската конфедерация по волейбол'}, {'FIVB': 'Международната федерация по волейбол'}, {'БНСФ': 'Българска национална спортна федерация'}, {'КИРВ': 'Комитет за игрите с ръчна топка'}, {'МОК': 'Международния олимпийски комитет'}, {'РСВ': 'Републиканска секция по волейбол'}, {'СИРТ': 'Съюз за игрите с ръчна топка'}], 'out_expansion': [{'cm': 'centimeter'}, {'m': 'meter'}, {'АС-23': 'Атлетик Слава 23'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИВБ': 'Международната федерация по волейбол'}, {'г.': 'година'}, {'дн.': 'днес'}, {'др.': 'други'}, {'т.е.': 'тоест'}, {'т.нар': 'така наречен'}]}
# [{'CEV': 'Европейската конфедерация по волейбол'}, {'FIVB': 'Международната федерация по волейбол'}, {'БНСФ': 'Българска национална спортна федерация'}, {'КИРВ': 'Комитет за игрите с ръчна топка'}, {'МОК': 'Международния олимпийски комитет'}, {'РСВ': 'Републиканска секция по волейбол'}, {'СИРТ': 'Съюз за игрите с ръчна топка'}]
# [{'cm': 'centimeter'}, {'m': 'meter'}, {'АС-23': 'Атлетик Слава 23'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИВБ': 'Международната федерация по волейбол'}, {'г.': 'година'}, {'дн.': 'днес'}, {'др.': 'други'}, {'т.е.': 'тоест'}, {'т.нар': 'така наречен'}]
# Временно_руско_управление
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'ВРУ': 'Временно руско управление'}], 'out_expansion': [{'г.': 'година'}, {'с.г.': 'същата година'}]}
# [{'ВРУ': 'Временно руско управление'}]
# [{'г.': 'година'}, {'с.г.': 'същата година'}]
# stella.vouteva@gmail.com
# {'in_expansion': [{'ВРУ': 'Временно руско управление'}], 'out_expansion': [{'г.': 'година'}]}
# [{'ВРУ': 'Временно руско управление'}]
# [{'г.': 'година'}]
# Гъвкав_магнитен_диск
# g.yordanov999@gmail.com
# {'out_expansion': [{'IBM': 'International Business Machines'}, {'KB': 'kilobytes'}, {'MB': 'megabytes'}, {'mm': 'millimetre'}, {'г.': 'година'}], 'in_expansion': [{'TPI': 'tracks-per-inch'}, {'boPET': 'biaxially-oriented polyethylene terephthalate'}, {'ФДУ': 'флопи-дисково устройство'}]}
# [{'TPI': 'tracks-per-inch'}, {'boPET': 'biaxially-oriented polyethylene terephthalate'}, {'ФДУ': 'флопи-дисково устройство'}]
# [{'IBM': 'International Business Machines'}, {'KB': 'kilobytes'}, {'MB': 'megabytes'}, {'mm': 'millimetre'}, {'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'IBM': 'International Business Machines'}, {'KB': 'Kilobyte'}, {'MB': 'Megabyte'}, {'boPET': 'biaxially-oriented polyethylene terephthalate'}, {'mm': 'millimeter'}, {'г.': 'година'}], 'in_expansion': [{'TPI': 'tracks-per-inch'}, {'ФДУ': 'флопи-дисково устройство'}]}
# [{'TPI': 'tracks-per-inch'}, {'ФДУ': 'флопи-дисково устройство'}]
# [{'IBM': 'International Business Machines'}, {'KB': 'Kilobyte'}, {'MB': 'Megabyte'}, {'boPET': 'biaxially-oriented polyethylene terephthalate'}, {'mm': 'millimeter'}, {'г.': 'година'}]
# Дисниленд
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'САЩ': 'Съединените Американски Щати'}, {'г-н': 'господин'}, {'г.': 'година'}, {'хил.': 'хиляди'}]}
# [{'САЩ': 'Съединените Американски Щати'}, {'г-н': 'господин'}, {'г.': 'година'}, {'хил.': 'хиляди'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'г.': 'година'}, {'хил.': 'хиляди'}]}
# [{'г.': 'година'}, {'хил.': 'хиляди'}]
# Драйвер
# g.yordanov999@gmail.com
# {'out_expansion': [{'FTDI': 'Future Technology Devices International'}, {'UART': 'Universal asynchronous receiver-transmitter'}, {'USB': 'Universal Serial Bus'}], 'in_expansion': [{'WDF': 'Windows Driver Foundation'}]}
# [{'WDF': 'Windows Driver Foundation'}]
# [{'FTDI': 'Future Technology Devices International'}, {'UART': 'Universal asynchronous receiver-transmitter'}, {'USB': 'Universal Serial Bus'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'FTDI': 'Future Technology Devices International'}, {'I/O': 'Input/Оutput'}, {'OS': 'Operating system'}, {'UART': 'Universal asynchronous receiver-transmitter'}, {'USB': 'Universal Serial Bus'}], 'in_expansion': [{'WDF': 'Windows Driver Foundation'}]}
# [{'WDF': 'Windows Driver Foundation'}]
# [{'FTDI': 'Future Technology Devices International'}, {'I/O': 'Input/Оutput'}, {'OS': 'Operating system'}, {'UART': 'Universal asynchronous receiver-transmitter'}, {'USB': 'Universal Serial Bus'}]
# Дуги_оток
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}, {'км': 'километър'}, {'км²': 'квадратен километър'}, {'м': 'метър'}, {'пр.н.е.': 'преди новата ера'}]}
# [{'г.': 'година'}, {'км': 'километър'}, {'км²': 'квадратен километър'}, {'м': 'метър'}, {'пр.н.е.': 'преди новата ера'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}, {'км': 'километър'}, {'км²': 'квадратен километър'}, {'м': 'метър'}, {'пр.н.е.': 'преди новата ера'}]}
# [{'г.': 'година'}, {'км': 'километър'}, {'км²': 'квадратен километър'}, {'м': 'метър'}, {'пр.н.е.': 'преди новата ера'}]
# Държавен_вестник
# g.yordanov999@gmail.com
# {'in_expansion': [{'ДВ': 'Държавен вестник'}], 'out_expansion': [{'г.': 'година'}, {'др.': 'други'}, {'млн.': 'милиона'}]}
# [{'ДВ': 'Държавен вестник'}]
# [{'г.': 'година'}, {'др.': 'други'}, {'млн.': 'милиона'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'ДВ': 'Държавен вестник'}], 'out_expansion': [{'г.': 'година'}, {'др.': 'други'}, {'млн.': 'милиона'}]}
# [{'ДВ': 'Държавен вестник'}]
# [{'г.': 'година'}, {'др.': 'други'}, {'млн.': 'милиона'}]
# Държавен_съвет_на_Народна_република_България
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българска комунистическа партия'}, {'НРБ': 'Народна Република България'}, {'НС': 'Народно Събрание'}, {'ЦК': 'Централния комитет'}, {'г.': 'година'}, {'чл.': 'член'}]}
# [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българска комунистическа партия'}, {'НРБ': 'Народна Република България'}, {'НС': 'Народно Събрание'}, {'ЦК': 'Централния комитет'}, {'г.': 'година'}, {'чл.': 'член'}]
# stella.vouteva@gmail.com
# {'out_expansion': [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българска комунистическа партия'}, {'НС': 'Народно събрание'}, {'ЦК': 'Централен комитет'}, {'вкл.': 'включително'}, {'г.': 'година'}, {'зам.': 'заместник'}, {'чл.': 'член'}], 'in_expansion': [{'НРБ': 'Народна Република България'}]}
# [{'НРБ': 'Народна Република България'}]
# [{'БЗНС': 'Български земеделски народен съюз'}, {'БКП': 'Българска комунистическа партия'}, {'НС': 'Народно събрание'}, {'ЦК': 'Централен комитет'}, {'вкл.': 'включително'}, {'г.': 'година'}, {'зам.': 'заместник'}, {'чл.': 'член'}]
# Европейска_централна_банка
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'ЕНМ': 'единния надзорен механизъм'}, {'ЕПИ': 'Европейския паричен институт'}, {'ЕС': 'Европейския съюз'}, {'ЕСЦБ': 'Европейската система на централните банки'}, {'ЕФФС': 'Европейския фонд за финансова стабилност'}, {'ЕЦБ': 'Европейската централна банка'}, {'НКО': 'националните компетентни органи'}, {'НЦБ': 'националните централни банки'}], 'out_expansion': [{'г.': 'година'}]}
# [{'ЕНМ': 'единния надзорен механизъм'}, {'ЕПИ': 'Европейския паричен институт'}, {'ЕС': 'Европейския съюз'}, {'ЕСЦБ': 'Европейската система на централните банки'}, {'ЕФФС': 'Европейския фонд за финансова стабилност'}, {'ЕЦБ': 'Европейската централна банка'}, {'НКО': 'националните компетентни органи'}, {'НЦБ': 'националните централни банки'}]
# [{'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'in_expansion': [{'ЕНМ': 'единния надзорен механизъм'}, {'ЕПИ': 'Европейския паричен институт'}, {'ЕС': 'Европейския съюз'}, {'ЕСЦБ': 'Европейската система на централните банки'}, {'ЕЦБ': 'Европейската централна банка'}, {'НКО': 'националните компетентни органи'}, {'НЦБ': 'националните централни банки'}], 'out_expansion': [{'ЕФФС': 'Европейския фонд за финансова стабилност'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]}
# [{'ЕНМ': 'единния надзорен механизъм'}, {'ЕПИ': 'Европейския паричен институт'}, {'ЕС': 'Европейския съюз'}, {'ЕСЦБ': 'Европейската система на централните банки'}, {'ЕЦБ': 'Европейската централна банка'}, {'НКО': 'националните компетентни органи'}, {'НЦБ': 'националните централни банки'}]
# [{'ЕФФС': 'Европейския фонд за финансова стабилност'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]
# Железният_човек
# georgitidorov4508@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# Закон_за_трудовата_поземлена_собственост
# g.yordanov999@gmail.com
# {'in_expansion': [{'БЗНС': 'Българския земеделски народен съюз'}, {'ТКЗС': 'Трудово-кооперативни земеделски стопанства'}], 'out_expansion': [{'ЗТПС': 'Закон за трудовата поземлена собственост'}]}
# [{'БЗНС': 'Българския земеделски народен съюз'}, {'ТКЗС': 'Трудово-кооперативни земеделски стопанства'}]
# [{'ЗТПС': 'Закон за трудовата поземлена собственост'}]
# georgitidorov4508@gmail.com
# {'in_expansion': [{'БЗНС': 'Българския земеделски народен съюз'}, {'ТКЗС': 'Трудово-кооперативни земеделски стопанства'}], 'out_expansion': [{'ЗТПС': 'Закон за трудовата поземлена собственост'}]}
# [{'БЗНС': 'Българския земеделски народен съюз'}, {'ТКЗС': 'Трудово-кооперативни земеделски стопанства'}]
# [{'ЗТПС': 'Закон за трудовата поземлена собственост'}]
# Златен_глобус
# georgitidorov4508@gmail.com
# {'out_expansion': [{'HFPA': 'Hollywood Foreign Press Association'}, {'САЩ': 'Съединени Американски Щати'}]}
# [{'HFPA': 'Hollywood Foreign Press Association'}, {'САЩ': 'Съединени Американски Щати'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'HFPA': 'Hollywood Foreign Press Association'}, {'САЩ': 'Съединени Американски Щати'}]}
# [{'HFPA': 'Hollywood Foreign Press Association'}, {'САЩ': 'Съединени Американски Щати'}]
# Иван_Славков
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'ВМЕИ': 'Висш машинно-електротехнически институт'}, {'ДС': 'Държавна сигурност'}, {'ПФК': 'Професионален футболен клуб'}, {'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}, {'ФИФА': 'Международната футболна федерация'}, {'ЦСКА': 'Централен спортен клуб на армията'}, {'г.': 'година'}, {'ч.': 'часа'}], 'in_expansion': [{'АЕНОК': 'Асамблеята на националните олимпийски комитети'}, {'БОК': 'Българския олимпийски комитет'}, {'БФС': 'Българския футболен съюз'}, {'МОК': 'Международния олимпийски комитет'}]}
# [{'АЕНОК': 'Асамблеята на националните олимпийски комитети'}, {'БОК': 'Българския олимпийски комитет'}, {'БФС': 'Българския футболен съюз'}, {'МОК': 'Международния олимпийски комитет'}]
# [{'BBC': 'British Broadcasting Corporation'}, {'ВМЕИ': 'Висш машинно-електротехнически институт'}, {'ДС': 'Държавна сигурност'}, {'ПФК': 'Професионален футболен клуб'}, {'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}, {'ФИФА': 'Международната футболна федерация'}, {'ЦСКА': 'Централен спортен клуб на армията'}, {'г.': 'година'}, {'ч.': 'часа'}]
# g.yordanov999@gmail.com
# {'out_expansion': [{'BBC': 'British Broadcasting Corporation'}, {'ВМЕИ': 'Висш машинно-електротехнически институт'}, {'ДС': 'Държавна сигурност'}, {'ПФК': 'Професионален футболен клуб'}, {'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}, {'ФИФА': 'Международна футболна федерация'}, {'ЦСКА': 'Централен спортен клуб на армията'}, {'г.': 'година'}], 'in_expansion': [{'АЕНОК': 'Асамблеята на националните олимпийски комитети'}, {'БОК': 'Българския олимпийски комитет'}, {'БФС': 'Българския футболен съюз'}, {'МОК': 'Международния олимпийски комитет'}]}
# [{'АЕНОК': 'Асамблеята на националните олимпийски комитети'}, {'БОК': 'Българския олимпийски комитет'}, {'БФС': 'Българския футболен съюз'}, {'МОК': 'Международния олимпийски комитет'}]
# [{'BBC': 'British Broadcasting Corporation'}, {'ВМЕИ': 'Висш машинно-електротехнически институт'}, {'ДС': 'Държавна сигурност'}, {'ПФК': 'Професионален футболен клуб'}, {'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}, {'ФИФА': 'Международна футболна федерация'}, {'ЦСКА': 'Централен спортен клуб на армията'}, {'г.': 'година'}]
# Изобразително_изкуство
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'CD-ROM': 'Compact Disc Read-Only Memory'}, {'DVD': 'Digital Video Disk'}, {'Хр.': 'Христа'}, {'в.': 'век'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.': 'преди'}]}
# [{'CD-ROM': 'Compact Disc Read-Only Memory'}, {'DVD': 'Digital Video Disk'}, {'Хр.': 'Христа'}, {'в.': 'век'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.': 'преди'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'3-D': 'three-dimensional'}, {'CD-ROM': 'Compact Disc Read-Only Memory'}, {'DVD': 'Digital Video Drive'}, {'в.': 'век'}, {'г.': 'година'}, {'пр. Хр.': 'преди христа'}]}
# [{'3-D': 'three-dimensional'}, {'CD-ROM': 'Compact Disc Read-Only Memory'}, {'DVD': 'Digital Video Drive'}, {'в.': 'век'}, {'г.': 'година'}, {'пр. Хр.': 'преди христа'}]
# Интегрална_схема
# georgitidorov4508@gmail.com
# {'out_expansion': [{'AG': 'Aktiengesellschaft'}, {'ASIC': 'application-specific integrated circuit'}, {'CMOS': 'Complementary metal–oxide–semiconductor'}, {'RAM': 'random-access memory'}, {'W': 'Watt'}, {'mm': 'millimeter'}, {'µm': 'micrometer'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'DSP': 'Digital Signal Processo'}, {'FPGA': 'Field Programmable Gate Arrays'}, {'АЦП': 'Аналогово-цифров преобразувател'}, {'ИС': 'Интегрална схема'}, {'ЦАП': 'Цифрово-аналогов преобразувател'}]}
# [{'DSP': 'Digital Signal Processo'}, {'FPGA': 'Field Programmable Gate Arrays'}, {'АЦП': 'Аналогово-цифров преобразувател'}, {'ИС': 'Интегрална схема'}, {'ЦАП': 'Цифрово-аналогов преобразувател'}]
# [{'AG': 'Aktiengesellschaft'}, {'ASIC': 'application-specific integrated circuit'}, {'CMOS': 'Complementary metal–oxide–semiconductor'}, {'RAM': 'random-access memory'}, {'W': 'Watt'}, {'mm': 'millimeter'}, {'µm': 'micrometer'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'CMOS': 'Complementary metal–oxide–semiconductor'}, {'AG': 'Aktiengesellschaft'}, {'ASIC': 'application-specific integrated circuit'}, {'RAM': 'random access memory'}, {'W': 'watt'}, {'mm': 'milimeter'}, {'µm': 'micrometer'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'DSP': 'Digital Signal Processor'}, {'FPGA': 'Field Programmable Gate Arrays'}, {'АЦП': 'Аналогово-цифров преобразувател'}, {'ИС': 'Интегрална схема'}, {'ЦАП': 'Цифрово-аналогов преобразувател'}]}
# [{'DSP': 'Digital Signal Processor'}, {'FPGA': 'Field Programmable Gate Arrays'}, {'АЦП': 'Аналогово-цифров преобразувател'}, {'ИС': 'Интегрална схема'}, {'ЦАП': 'Цифрово-аналогов преобразувател'}]
# [{'CMOS': 'Complementary metal–oxide–semiconductor'}, {'AG': 'Aktiengesellschaft'}, {'ASIC': 'application-specific integrated circuit'}, {'RAM': 'random access memory'}, {'W': 'watt'}, {'mm': 'milimeter'}, {'µm': 'micrometer'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}]
# Интел
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'AGP': 'Accelerated Graphics Port'}, {'DEC': 'Disasters Emergency Committee'}, {'DRAM': 'Dynamic random-access memory'}, {'ENIAC': 'Electronic Numerical Integrator And Computer'}, {'FTC': 'The Federal Trade Commission'}, {'IBM': 'International Business Machines Corporation'}, {'INTC': 'Intel Corporation Common Stock'}, {'MOS': 'metal–oxide–silicon'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NASDAQ': 'National Association of Securities Dealers Automated Quotations'}, {'NCM': 'Nippon Calculating Machine Corporation'}, {'PC': 'Personal Computer'}, {'PCI': 'Peripheral Component Interconnect'}, {'ROM': 'Read-only memory'}, {'SRAM': 'Static Random Access Memory'}, {'TTL': 'Transistor–transistor Logic'}, {'USB': 'Universal Serial Bus'}, {'САЩ': 'Съединените Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'AMD': 'Advanced Micro Devices'}]}
# [{'AMD': 'Advanced Micro Devices'}]
# [{'AGP': 'Accelerated Graphics Port'}, {'DEC': 'Disasters Emergency Committee'}, {'DRAM': 'Dynamic random-access memory'}, {'ENIAC': 'Electronic Numerical Integrator And Computer'}, {'FTC': 'The Federal Trade Commission'}, {'IBM': 'International Business Machines Corporation'}, {'INTC': 'Intel Corporation Common Stock'}, {'MOS': 'metal–oxide–silicon'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NASDAQ': 'National Association of Securities Dealers Automated Quotations'}, {'NCM': 'Nippon Calculating Machine Corporation'}, {'PC': 'Personal Computer'}, {'PCI': 'Peripheral Component Interconnect'}, {'ROM': 'Read-only memory'}, {'SRAM': 'Static Random Access Memory'}, {'TTL': 'Transistor–transistor Logic'}, {'USB': 'Universal Serial Bus'}, {'САЩ': 'Съединените Американски Щати'}, {'г.': 'година'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'AGP': 'accelerated graphics port'}, {'DEC': 'Digital Equipment Corporation'}, {'DRAM': 'dynamic random access memory'}, {'ENIAC': 'Electronic Numerical Integrator and Computer'}, {'IBM': 'International Business Machines'}, {'IN': ''}, {'INTC': 'International Nonwovens Technical Conference'}, {'MOS': 'metal oxide semiconductor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NASDAQ': 'National Association of Securities Dealers Automated Quotations'}, {'PC': 'Personal computer'}, {'PCI': 'Peripheral Component Interconnect'}, {'ROM': 'Read-only memory'}, {'SRAM': 'Static Random Access Memory'}, {'TTL': 'transistor-transistor logic'}, {'USB': 'Universal Serial Bus'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}], 'in_expansion': [{'AMD': 'Advanced Micro Devices'}, {'FTC': 'Федералната търговска комисия'}, {'NCM': 'Nippon Calculating Machine Corporation'}]}
# [{'AMD': 'Advanced Micro Devices'}, {'FTC': 'Федералната търговска комисия'}, {'NCM': 'Nippon Calculating Machine Corporation'}]
# [{'AGP': 'accelerated graphics port'}, {'DEC': 'Digital Equipment Corporation'}, {'DRAM': 'dynamic random access memory'}, {'ENIAC': 'Electronic Numerical Integrator and Computer'}, {'IBM': 'International Business Machines'}, {'IN': ''}, {'INTC': 'International Nonwovens Technical Conference'}, {'MOS': 'metal oxide semiconductor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NASDAQ': 'National Association of Securities Dealers Automated Quotations'}, {'PC': 'Personal computer'}, {'PCI': 'Peripheral Component Interconnect'}, {'ROM': 'Read-only memory'}, {'SRAM': 'Static Random Access Memory'}, {'TTL': 'transistor-transistor logic'}, {'USB': 'Universal Serial Bus'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}]
# Ирландия
# georgitidorov4508@gmail.com
# {'out_expansion': [{'km2': 'Square kilometer'}, {'m': 'meter'}, {'mm': 'milimeter'}, {'°С': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ЕС': 'Европейски съюз'}, {'ИРА': 'Републиканската армия'}, {'ИЧР': 'Индекс на човешкото развитие'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ОИСР': 'Организация за икономическо сътрудничество и развитие'}, {'ООН': 'Организация на обединените нации'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.н.е.': 'преди новата ера'}]}
# [{'km2': 'Square kilometer'}, {'m': 'meter'}, {'mm': 'milimeter'}, {'°С': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ЕС': 'Европейски съюз'}, {'ИРА': 'Републиканската армия'}, {'ИЧР': 'Индекс на човешкото развитие'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ОИСР': 'Организация за икономическо сътрудничество и развитие'}, {'ООН': 'Организация на обединените нации'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.н.е.': 'преди новата ера'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'km2': 'Square kilometer'}, {'m': 'meter'}, {'mm': 'milimeter'}, {'°С': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ЕС': 'Европейски съюз'}, {'ИЧР': 'Индекс на човешкото развитие'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ОИСР': 'Организация за икономическо сътрудничество и развитие'}, {'ООН': 'Организация на обединените нации'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.н.е.': 'преди новата ера'}], 'in_expansion': [{'ИРА': 'Републиканската армия'}]}
# [{'ИРА': 'Републиканската армия'}]
# [{'km2': 'Square kilometer'}, {'m': 'meter'}, {'mm': 'milimeter'}, {'°С': 'Celsius'}, {'БВП': 'Брутен вътрешен продукт'}, {'ЕС': 'Европейски съюз'}, {'ИЧР': 'Индекс на човешкото развитие'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ОИСР': 'Организация за икономическо сътрудничество и развитие'}, {'ООН': 'Организация на обединените нации'}, {'г.': 'година'}, {'др.': 'други'}, {'пр.н.е.': 'преди новата ера'}]
# Капитан_Америка
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'Dr.': 'Doctor'}, {'Д-р': 'доктор'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограма'}, {'км': 'километра'}]}
# [{'Dr.': 'Doctor'}, {'Д-р': 'доктор'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограма'}, {'км': 'километра'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'Dr.': 'Doctor'}, {'Д-р': 'доктор'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограма'}, {'км': 'километра'}]}
# [{'Dr.': 'Doctor'}, {'Д-р': 'доктор'}, {'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'кг': 'килограма'}, {'км': 'километра'}]
# Княжество_България
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'ВРУ': 'Временно Руско управление'}, {'ДВ': 'Държавен вестник'}, {'ОНС': 'Обикновено народно събрание'}, {'бр.': 'брой'}, {'г.': 'година'}, {'км²': 'квадратни километри'}, {'чл.': 'член'}]}
# [{'ВРУ': 'Временно Руско управление'}, {'ДВ': 'Държавен вестник'}, {'ОНС': 'Обикновено народно събрание'}, {'бр.': 'брой'}, {'г.': 'година'}, {'км²': 'квадратни километри'}, {'чл.': 'член'}]
# stella.vouteva@gmail.com
# {'out_expansion': [{'ВРУ': 'Временно руско управление'}, {'ДВ': 'Държавен Вестник'}, {'ОНС': 'Обикновено народно събрание'}, {'бр.': 'брой'}, {'г.': 'година'}, {'км': 'километра'}, {'чл.': 'член'}]}
# [{'ВРУ': 'Временно руско управление'}, {'ДВ': 'Държавен Вестник'}, {'ОНС': 'Обикновено народно събрание'}, {'бр.': 'брой'}, {'г.': 'година'}, {'км': 'километра'}, {'чл.': 'член'}]
# Конституционен_съд_на_България
# g.yordanov999@gmail.com
# {'out_expansion': [{'ДПС': 'Движение за права и свободи'}, {'ЕС': 'Европейски съюз'}, {'НС': 'Народно събрание'}, {'РБ': 'Република България'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'т. нар': 'така наречен'}, {'чл.': 'член'}], 'in_expansion': [{'КС': 'Конституционният съд'}]}
# [{'КС': 'Конституционният съд'}]
# [{'ДПС': 'Движение за права и свободи'}, {'ЕС': 'Европейски съюз'}, {'НС': 'Народно събрание'}, {'РБ': 'Република България'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'т. нар': 'така наречен'}, {'чл.': 'член'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'ЕС': 'Европейски съюз'}, {'НС': 'Народно събрание'}, {'РБ': 'Република България'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}], 'in_expansion': [{'КС': 'Конституционният съд'}]}
# [{'КС': 'Конституционният съд'}]
# [{'ЕС': 'Европейски съюз'}, {'НС': 'Народно събрание'}, {'РБ': 'Република България'}, {'ал.': 'алинея'}, {'г.': 'година'}, {'т.': 'точка'}, {'чл.': 'член'}]
# Крис_Евънс
# georgitidorov4508@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# Леброн_Джеймс
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'MVP': 'Most Valuable Player'}, {'NBA': 'National Basketball Association'}, {'ЛА': 'Лос Анджелис'}, {'НБА': 'Национална баскетболна асоциация'}, {'г.': 'година'}, {'кг': 'килограм'}, {'см': 'сантиметър'}]}
# [{'MVP': 'Most Valuable Player'}, {'NBA': 'National Basketball Association'}, {'ЛА': 'Лос Анджелис'}, {'НБА': 'Национална баскетболна асоциация'}, {'г.': 'година'}, {'кг': 'килограм'}, {'см': 'сантиметър'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'MVP': 'Most Valuable Player'}, {'NBA': 'National Basketball Association'}, {'ЛА': 'Лос Анджелис'}, {'НБА': 'Национална баскетболна асоциация'}, {'г.': 'година'}, {'кг': 'килограм'}, {'см': 'сантиметър'}]}
# [{'MVP': 'Most Valuable Player'}, {'NBA': 'National Basketball Association'}, {'ЛА': 'Лос Анджелис'}, {'НБА': 'Национална баскетболна асоциация'}, {'г.': 'година'}, {'кг': 'килограм'}, {'см': 'сантиметър'}]
# Лека_атлетика
# stella.vouteva@gmail.com
# {'in_expansion': [{'EAA': 'Европейската асоциация по лека атлетика'}, {'IAAF': 'Международната асоциация на лекоатлетическите федерации'}, {'БФЛА': 'Българската федерация по лека атлетика'}, {'ИААФ': 'Международната асоциация на лекоатлетическите федерации'}], 'out_expansion': [{'САЩ': 'Съединени Американски Щати'}]}
# [{'EAA': 'Европейската асоциация по лека атлетика'}, {'IAAF': 'Международната асоциация на лекоатлетическите федерации'}, {'БФЛА': 'Българската федерация по лека атлетика'}, {'ИААФ': 'Международната асоциация на лекоатлетическите федерации'}]
# [{'САЩ': 'Съединени Американски Щати'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'EAA': 'Европейската асоциация по лека атлетика'}, {'IAAF': 'Международната асоциация на лекоатлетическите федерации'}, {'БФЛА': 'Българската федерация по лека атлетика'}, {'ИААФ': 'Международната асоциация на лекоатлетическите федерации'}], 'out_expansion': [{'САЩ': 'Съединени Американски Щати'}, {'г.': 'година'}, {'км': 'километър'}, {'пр.н.е.': 'преди новата ера'}, {'т.е.': 'тоест'}]}
# [{'EAA': 'Европейската асоциация по лека атлетика'}, {'IAAF': 'Международната асоциация на лекоатлетическите федерации'}, {'БФЛА': 'Българската федерация по лека атлетика'}, {'ИААФ': 'Международната асоциация на лекоатлетическите федерации'}]
# ...
# Стокхолмски_синдром
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'ФБР': 'Федерално бюро за разследване'}, {'т.н.': 'така нататък'}]}
# [{'ФБР': 'Федерално бюро за разследване'}, {'т.н.': 'така нататък'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'ФБР': 'Федерално бюро за разследване'}, {'т.н.': 'така нататък'}]}
# [{'ФБР': 'Федерално бюро за разследване'}, {'т.н.': 'така нататък'}]
# Съюз_на_българските_автомобилисти
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'AIT': 'Международния алианс по туризъм'}, {'ARC': 'Международната организация за пътна помощ'}, {'FIA': 'Международната автомобилна федерация'}, {'FICC': 'Международната организация по къмпинг и караванинг'}, {'БАТК': 'Български автомобилен и туринг клуб'}, {'СБА': 'Съюзът на българските автомобилисти'}]}
# [{'AIT': 'Международния алианс по туризъм'}, {'ARC': 'Международната организация за пътна помощ'}, {'FIA': 'Международната автомобилна федерация'}, {'FICC': 'Международната организация по къмпинг и караванинг'}, {'БАТК': 'Български автомобилен и туринг клуб'}, {'СБА': 'Съюзът на българските автомобилисти'}]
# g.yordanov999@gmail.com
# {'out_expansion': [{'AIT': 'Alliance Internationale de Tourisme'}, {'ARC': 'Automotive Research Center'}, {'FIA': "Fédération Internationale de l'Automobile"}, {'FICC': 'Fédération Internationale de Camping, Caravanning et Autocaravaning'}], 'in_expansion': [{'БАТК': 'Български автомобилен и туринг клуб'}, {'СБА': 'Съюзът на българските автомобилисти'}]}
# [{'БАТК': 'Български автомобилен и туринг клуб'}, {'СБА': 'Съюзът на българските автомобилисти'}]
# [{'AIT': 'Alliance Internationale de Tourisme'}, {'ARC': 'Automotive Research Center'}, {'FIA': "Fédération Internationale de l'Automobile"}, {'FICC': 'Fédération Internationale de Camping, Caravanning et Autocaravaning'}]
# ТАБСО
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'СССР': 'Съюз на съветските социалистически републики'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}], 'in_expansion': [{'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}]}
# [{'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}]
# [{'СССР': 'Съюз на съветските социалистически републики'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'СССР': 'Съюз на съветските социалистически републики'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}], 'in_expansion': [{'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}]}
# [{'ТАБСО': 'Транспортно-авиационно българо-съветско общество'}]
# [{'СССР': 'Съюз на съветските социалистически републики'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'хил.': 'хиляди'}]
# Табулираща_машина
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'IBM': 'International Business Machines'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]}
# [{'IBM': 'International Business Machines'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'IBM': 'International Business Machines'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]}
# [{'IBM': 'International Business Machines'}, {'г.': 'година'}, {'т.н.': 'така нататък'}]
# Транзистор
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'FET': 'field-effect transistor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NPN': 'Negative, Positive, Negative'}, {'PNP': 'Positive, Negative, Positive'}, {'МОП': 'металл-оксид-полупроводник'}]}
# [{'FET': 'field-effect transistor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NPN': 'Negative, Positive, Negative'}, {'PNP': 'Positive, Negative, Positive'}, {'МОП': 'металл-оксид-полупроводник'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'FET': 'Field-effect transistor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NPN': 'Negative, Positive, Negative'}, {'PNP': 'Positive, Negative, Positive'}, {'W': 'Watt'}, {'МОП': 'метал-оксид-полупроводник'}, {'др.': 'други'}, {'т.е.': 'тоест'}, {'т.нар.': 'така нарачените'}]}
# [{'FET': 'Field-effect transistor'}, {'MOSFET': 'metal-oxide-semiconductor field-effect transistor'}, {'NPN': 'Negative, Positive, Negative'}, {'PNP': 'Positive, Negative, Positive'}, {'W': 'Watt'}, {'МОП': 'метал-оксид-полупроводник'}, {'др.': 'други'}, {'т.е.': 'тоест'}, {'т.нар.': 'така нарачените'}]
# Тримерен_печат
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'.3ds': '3D Studio'}, {'.OBJ': ''}, {'.dae': 'Digital Asset Exchange File Format'}, {'.skp': 'SketchUp'}, {'3D': 'three-dimensional'}, {'AEC': 'Architecture Engineering and Construction'}, {'CNC': 'Computer Numerical Control'}, {'FDM': 'Fused Deposition Modeling'}, {'STL': ''}, {'г.': 'година'}, {'щ.д': 'щатски долата'}], 'in_expansion': [{'CAD': 'computer aided design'}, {'АП': 'адитивно производство'}]}
# [{'CAD': 'computer aided design'}, {'АП': 'адитивно производство'}]
# [{'.3ds': '3D Studio'}, {'.OBJ': ''}, {'.dae': 'Digital Asset Exchange File Format'}, {'.skp': 'SketchUp'}, {'3D': 'three-dimensional'}, {'AEC': 'Architecture Engineering and Construction'}, {'CNC': 'Computer Numerical Control'}, {'FDM': 'Fused Deposition Modeling'}, {'STL': ''}, {'г.': 'година'}, {'щ.д': 'щатски долата'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'3-D': 'three-dimensional'}, {'AEC': 'Architecture, Engineering, and Construction'}, {'CAD': 'Computer-aided design'}, {'CNC': 'Computerized Numerical Control'}, {'DPI': 'Dots per inch'}, {'STL': 'Standard Triangle Language'}, {'µm': 'micrometer'}, {'г.': 'година'}, {'млн.': 'милион'}], 'in_expansion': [{'BAAM': 'Big Area Additive Manufacturing'}, {'АП': 'адитивно производство'}]}
# [{'BAAM': 'Big Area Additive Manufacturing'}, {'АП': 'адитивно производство'}]
# [{'3-D': 'three-dimensional'}, {'AEC': 'Architecture, Engineering, and Construction'}, {'CAD': 'Computer-aided design'}, {'CNC': 'Computerized Numerical Control'}, {'DPI': 'Dots per inch'}, {'STL': 'Standard Triangle Language'}, {'µm': 'micrometer'}, {'г.': 'година'}, {'млн.': 'милион'}]
# Уеб_сървър
# g.yordanov999@gmail.com
# {'out_expansion': [{'CGI': 'Computer-generated imagery'}, {'GIF': 'Graphics Interchange Format'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'JPEG': 'Joint Photographic Experts Group'}, {'PNG': 'Portable Network Graphics'}, {'XML': 'Extensible Markup Language'}, {'т. нар.': 'така наречен'}, {'т.е.': 'тоест'}]}
# [{'CGI': 'Computer-generated imagery'}, {'GIF': 'Graphics Interchange Format'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'JPEG': 'Joint Photographic Experts Group'}, {'PNG': 'Portable Network Graphics'}, {'XML': 'Extensible Markup Language'}, {'т. нар.': 'така наречен'}, {'т.е.': 'тоест'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'CGI': 'Computer-Generated Imagery'}, {'GIF': 'Graphics Interchange Format'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'JPEG': 'Joint Photographic Experts Group'}, {'PNG': 'Portable Network Graphics'}, {'XML': 'Extensible Markup Language'}, {'т. нар.': 'така наречен'}]}
# [{'CGI': 'Computer-Generated Imagery'}, {'GIF': 'Graphics Interchange Format'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'JPEG': 'Joint Photographic Experts Group'}, {'PNG': 'Portable Network Graphics'}, {'XML': 'Extensible Markup Language'}, {'т. нар.': 'така наречен'}]
# Уебстраница
# g.yordanov999@gmail.com
# {'out_expansion': [{'CSS': 'Cascading Style Sheets'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'URL': 'Uniform Resource Locator'}, {'XHTML': 'Extensible HyperText Markup Language'}, {'вкл.': 'включително'}, {'др.': 'друг'}]}
# [{'CSS': 'Cascading Style Sheets'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'URL': 'Uniform Resource Locator'}, {'XHTML': 'Extensible HyperText Markup Language'}, {'вкл.': 'включително'}, {'др.': 'друг'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'CSS': 'Cascading Style Sheets'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'URL': 'Uniform Resource Locator'}, {'XHTML': 'Extensible HyperText Markup Language'}]}
# [{'CSS': 'Cascading Style Sheets'}, {'HTML': 'HyperText Markup Language'}, {'HTTP': 'Hypertext Transfer Protocol'}, {'URL': 'Uniform Resource Locator'}, {'XHTML': 'Extensible HyperText Markup Language'}]
# Фестивал
# g.yordanov999@gmail.com
# {'in_expansion': [{'ЕАФ': 'Европейската асоциация на фестивалите'}]}
# [{'ЕАФ': 'Европейската асоциация на фестивалите'}]
# georgitidorov4508@gmail.com
# {'in_expansion': [{'ЕАФ': 'Европейската асоциация на фестивалите'}]}
# [{'ЕАФ': 'Европейската асоциация на фестивалите'}]
# ФК_Ювентус
# g.yordanov999@gmail.com
# {'out_expansion': [{'КЕШ': 'Купата на европейските шампиони'}, {'САЩ': 'Съединени Американски Щати'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ФК': 'Футболен клуб'}, {'г.': 'година'}, {'млн': 'милиона'}]}
# [{'КЕШ': 'Купата на европейските шампиони'}, {'САЩ': 'Съединени Американски Щати'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ФК': 'Футболен клуб'}, {'г.': 'година'}, {'млн': 'милиона'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ФК': 'Футболен клуб'}, {'бул.': 'булевард'}, {'г.': 'година'}, {'млн.': 'милион'}]}
# [{'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'ФК': 'Футболен клуб'}, {'бул.': 'булевард'}, {'г.': 'година'}, {'млн.': 'милион'}]
# Формула_1
# g.yordanov999@gmail.com
# {'out_expansion': [{'ABS': 'Anti-lock braking system'}, {'TCS': 'Traction control system'}, {'km': 'kilometer'}, {'km/h': 'kilometers per hour'}, {'mm': 'millimeter'}, {'НБО': 'най-бърза обиколка'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИА': 'Международна автомобилна федерация'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'т.': 'точка'}, {'т.н.': 'така нататък'}]}
# [{'ABS': 'Anti-lock braking system'}, {'TCS': 'Traction control system'}, {'km': 'kilometer'}, {'km/h': 'kilometers per hour'}, {'mm': 'millimeter'}, {'НБО': 'най-бърза обиколка'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИА': 'Международна автомобилна федерация'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'т.': 'точка'}, {'т.н.': 'така нататък'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'ABS': 'Anti-lock braking system'}, {'TCS': 'Traction control system'}, {'km': 'kilometer'}, {'km/h': 'kilometers per hour'}, {'mm': 'milimeters'}, {'НБО': 'най-бърза обиколка'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИА': 'Международна автомобилна федерация'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'об/мин': 'оборота на минута'}, {'т.': 'точка'}]}
# [{'ABS': 'Anti-lock braking system'}, {'TCS': 'Traction control system'}, {'km': 'kilometer'}, {'km/h': 'kilometers per hour'}, {'mm': 'milimeters'}, {'НБО': 'най-бърза обиколка'}, {'САЩ': 'Съединени Американски Щати'}, {'ФИА': 'Международна автомобилна федерация'}, {'г.': 'година'}, {'млн.': 'милиона'}, {'об/мин': 'оборота на минута'}, {'т.': 'точка'}]
# Хановер
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# Хокей_на_лед
# tachevy001@gmail.com
# {'out_expansion': [{'НХЛ': 'Национална Хокейна Лига'}], 'in_expansion': [{'САЩ': 'Съединените Американски Щати'}]}
# [{'САЩ': 'Съединените Американски Щати'}]
# [{'НХЛ': 'Национална Хокейна Лига'}]
# violeta.todorovaaa@gmail.com
# {'in_expansion': [{'НХЛ': 'Националната хокейна лига на САЩ и Канада'}], 'out_expansion': [{'г.': 'година'}, {'км': 'километър'}, {'м': 'метър'}, {'мм': 'милиметър'}, {'см': 'сантиметър'}]}
# [{'НХЛ': 'Националната хокейна лига на САЩ и Канада'}]
# [{'г.': 'година'}, {'км': 'километър'}, {'м': 'метър'}, {'мм': 'милиметър'}, {'см': 'сантиметър'}]
# Хоум_Бокс_Офис
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'HBO': 'Home Box Office'}], 'out_expansion': [{'HD': 'High-definition'}, {'MMDS': 'Multichannel Multipoint Distribution Service'}, {'САЩ': 'Съединените Американски Щати'}, {'ТВ': 'Телевизия'}, {'г.': 'година'}, {'млн.': 'милион'}]}
# [{'HBO': 'Home Box Office'}]
# [{'HD': 'High-definition'}, {'MMDS': 'Multichannel Multipoint Distribution Service'}, {'САЩ': 'Съединените Американски Щати'}, {'ТВ': 'Телевизия'}, {'г.': 'година'}, {'млн.': 'милион'}]
# georgitidorov4508@gmail.com
# {'in_expansion': [{'HBO': 'Home Box Office'}], 'out_expansion': [{'HD': 'high-definition'}, {'MMDS': 'Multi Media Distribution Systems'}, {'TV': 'Television'}, {'САЩ': 'Съединени Американски Щати'}, {'ТВ': 'телевизор'}, {'г.': 'година'}, {'млн.': 'милион'}]}
# [{'HBO': 'Home Box Office'}]
# [{'HD': 'high-definition'}, {'MMDS': 'Multi Media Distribution Systems'}, {'TV': 'Television'}, {'САЩ': 'Съединени Американски Щати'}, {'ТВ': 'телевизор'}, {'г.': 'година'}, {'млн.': 'милион'}]
# Христо_Ботев
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'БРЦК': 'Българския революционен централен комитет'}], 'out_expansion': [{'г.': 'година'}, {'др.': 'други'}]}
# [{'БРЦК': 'Българския революционен централен комитет'}]
# [{'г.': 'година'}, {'др.': 'други'}]
# stella.vouteva@gmail.com
# {'in_expansion': [{'БРЦК': 'Български революционен централен комитет'}], 'out_expansion': [{'г.': 'година'}, {'др.': 'други'}]}
# [{'БРЦК': 'Български революционен централен комитет'}]
# [{'г.': 'година'}, {'др.': 'други'}]
# Хълк
# georgitidorov4508@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# petya.stoyanovaaaa@gmail.com
# {'out_expansion': [{'г.': 'година'}]}
# [{'г.': 'година'}]
# Хърватия
# g.yordanov999@gmail.com
# {'out_expansion': [{'km': 'kilometer'}, {'km2': 'Square kilometer'}, {'km²': 'Square kilometer'}, {'°C': 'Celsius'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ЦЕФТА': 'Централноевропейско споразумение за свободна търговия'}, {'г.': 'година'}], 'in_expansion': [{'ООН': 'Организацията на обединените нации'}, {'СХС': 'сърби, хървати и словенци'}]}
# [{'ООН': 'Организацията на обединените нации'}, {'СХС': 'сърби, хървати и словенци'}]
# [{'km': 'kilometer'}, {'km2': 'Square kilometer'}, {'km²': 'Square kilometer'}, {'°C': 'Celsius'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ЦЕФТА': 'Централноевропейско споразумение за свободна търговия'}, {'г.': 'година'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'km': 'kilometer'}, {'km2': 'Square kilometer'}, {'km²': 'Square kilometer'}, {'°C': 'Celsius'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ЦЕФТА': 'Централноевропейско споразумение за свободна търговия'}, {'г.': 'година'}], 'in_expansion': [{'ООН': 'Организацията на обединените нации'}, {'СХС': 'сърби, хървати и словенци'}]}
# [{'ООН': 'Организацията на обединените нации'}, {'СХС': 'сърби, хървати и словенци'}]
# [{'km': 'kilometer'}, {'km2': 'Square kilometer'}, {'km²': 'Square kilometer'}, {'°C': 'Celsius'}, {'НАТО': 'Организацията на Северноатлантическия договор'}, {'ЦЕФТА': 'Централноевропейско споразумение за свободна търговия'}, {'г.': 'година'}]
# Чип
# dsgeorgiev90@yahoo.com
# {'out_expansion': [{'SiO2': 'Silicon dioxide'}, {'напр.': 'например'}]}
# [{'SiO2': 'Silicon dioxide'}, {'напр.': 'например'}]
# georgitidorov4508@gmail.com
# {'out_expansion': [{'напр.': 'например'}]}
# [{'напр.': 'например'}]
# Шампионска_лига_на_УЕФА
# dsgeorgiev90@yahoo.com
# {'in_expansion': [{'AG': 'Aktiengesellschaft'}, {'КЕШ': 'Купа на европейските шампиони'}], 'out_expansion': [{'ECC': "European Champions' Cup"}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'г.': 'година'}]}
# [{'AG': 'Aktiengesellschaft'}, {'КЕШ': 'Купа на европейските шампиони'}]
# [{'ECC': "European Champions' Cup"}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}, {'г.': 'година'}]
# violeta.todorovaaa@gmail.com
# {'out_expansion': [{'AG': 'Aktiengesellschaft'}, {'г.': 'година'}], 'in_expansion': [{'ECC': "European Champions' Cup"}, {'КЕШ': 'Купа на европейските шампиони'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}]}
# [{'ECC': "European Champions' Cup"}, {'КЕШ': 'Купа на европейските шампиони'}, {'УЕФА': 'Съюзът на европейските футболни асоциации'}]
# [{'AG': 'Aktiengesellschaft'}, {'г.': 'година'}]

# %% [markdown]
# ## Adding clean documents to the clean data

# %%
all_dirty =  dirt_2 + dirt_1
doc_subs = set.union(already_clean_docs, all_dirty)


all_docs = set(annotation_df['doc_id'])
good_docs = all_docs - doc_subs
print('Clean documents: \n{}'.format(good_docs))

clean_annotations = pd.DataFrame(columns=['acronym', 'expansion', 'language', 'type'])

# adding all clean documents together
clean_doc_all = pd.DataFrame(columns=['acronym', 'expansion','language', 'type', 'doc_id','annotator'])

for i in good_docs:
    df_empty = pd.DataFrame(columns=['acronym', 'expansion','language', 'type', 'doc_id','annotator'])
    sub_df = annotation_df[annotation_df['doc_id'] == i]
    clean_doc = pd.concat([df_empty, sub_df])
    clean_doc_all = pd.concat([clean_doc_all, clean_doc])
    
if set(clean_doc_all['doc_id']) == good_docs:
    print('\nAll good')
    

clean_annotations = pd.concat([clean_annotations, clean_doc_all])

# Save the changes in the main .csv file
# clean_annotations.to_csv('./clean_data/clean_annotations_nl.csv', index=False)
# Out:
# Clean documents:
# set()
#
# All good

# %% [markdown]
# ## Manual cleaning<a class="anchor" id="Manual-cleaning"></a>

# %%
print(annotation_df.iloc[18, 1])
print(annotation_df.iloc[1, 1])
# Out:
# Година
# Celsius

# %%
# show the annotations that have issues
document = "Шампионска_лига_на_УЕФА"

sub_set_df = annotation_df[annotation_df['doc_id'] == document]
sub_set_df.drop_duplicates(subset=["acronym", "expansion"], keep=False).sort_values(by='acronym')
# Out:
# Empty DataFrame
# Columns: [acronym, expansion, language, type, doc_id, annotator]
# Index: []

# %%
# Fill in the index to see of the values are the same
row_num_1 = 12
row_num_2 = 18

# Results
print("Are the acronyms the same:")
print(annotation_df.iloc[row_num_1, 0] == annotation_df.iloc[row_num_2, 0])
print("\nAre the expansion the same:")
print(annotation_df.iloc[row_num_1, 1] == annotation_df.iloc[row_num_2, 1])
print(annotation_df.iloc[row_num_1, 1])
print(annotation_df.iloc[row_num_2, 1])
# Out:
# Are the acronyms the same:
# True
#
# Are the expansion the same:
# True
# година
# година

# %%
pd.set_option('display.max_rows', None)
# fill in the index of the cell you want to change
# annotation_df.iloc[1296, 1] = "Български революционен централен комитет"
# annotation_df.iloc[1290, 1] = "Multichannel Multipoint Distribution Service"
# annotation_df.iloc[1284, 1] = "Съединени Американски Щати"
# annotation_df.iloc[1293, 1] = "Телевизия"

# Use the code below if you need toadd a new row
# extra_row = {'acronym':'m²', 'expansion':'squared metre', 'language':'en', 'type':'out_expansion', 'doc_id':document, 'annotator':'contact@iliyasgeorgiev.com'}
extra_row = {'acronym':'SiO2', 'expansion':'Silicon dioxide', 'language':'en', 'type':'out_expansion', 'doc_id':document, 'annotator':'contact@iliyasgeorgiev.com'}
# extra_row = {'acronym':'IBM', 'expansion':'International Business Machines Corporation', 'language':'en', 'type':'in_expansion', 'doc_id':document, 'annotator':'contact@iliyasgeorgiev.com'}
# extra_row = {'acronym':'Хр.', 'expansion':'Христа', 'language':'bg', 'type':'out_expansion', 'doc_id':document, 'annotator':'contact@iliyasgeorgiev.com'}
# extra_row = {'acronym':'AG', 'expansion':'Aktiengesellschaft', 'language':'none_of_above', 'type':'out_expansion', 'doc_id':document, 'annotator':'contact@iliyasgeorgiev.com'}


# Show the results
# delete row
# annotation_df = annotation_df.drop([508])
# annotation_df = annotation_df.delete(508, ignore_index=True)
annotation_df = annotation_df.append(extra_row, ignore_index = True)         # <-- uncomment if you need to add a extra row
annotation_df.to_csv('./clean_data/clean_annotations_2.csv', index=False)
results = annotation_df[annotation_df['doc_id'] == document]  
results.sort_values(by='acronym')
# Out:
#      acronym        expansion language           type doc_id  \
# 1322    SiO2  Silicon dioxide       en  out_expansion    Чип
# 1506    SiO2  Silicon dioxide       en  out_expansion    Чип
# 1323   напр.         например       bg  out_expansion    Чип
# 1324   напр.         например       bg  out_expansion    Чип
#
#                         annotator
# 1322       dsgeorgiev90@yahoo.com
# 1506   contact@iliyasgeorgiev.com
# 1323       dsgeorgiev90@yahoo.com
# 1324  georgitidorov4508@gmail.com

# %%
# results.drop(565, inplace=True)

# %% [markdown]
# ## Saving the changes<a class="anchor" id=""></a>

# %%
# # Save the changes
df_empty = pd.DataFrame(columns=['acronym', 'expansion','language', 'type', 'doc_id','annotator'])
clean_annotations_sub = pd.concat([df_empty, results])
clean_annotations = pd.concat([clean_annotations, clean_annotations_sub])

# Save the changes in the main .csv file
clean_annotations.to_csv('./clean_data/clean_annotations.csv', index=False)

# %%
set(clean_annotations['doc_id'].sort_values())
# Out:
# {'Conus_eugrammatus',
#  'JavaScript',
#  'UML',
#  'Административен_акт',
#  'Акционерно_дружество',
#  'Американска_психологична_асоциация',
#  'Амстердамски_университет',
#  'БНТ_1',
#  'БНТ_2',
#  'Банкова_консолидационна_компания',
#  'Баркод',
#  'Берлин',
#  'Би_Би_Си',
#  'Би_Ти_Ви',
#  'Бобслей',
#  'Ботаника',
#  'Българска_народна_банка',
#  'Българска_социалистическа_партия',
#  'Васил_Левски',
#  'Водноелектрическа_централа',
#  'Волейбол',
#  'Временно_руско_управление',
#  'Гъвкав_магнитен_диск',
#  'Дисниленд',
#  'Драйвер',
#  'Дуги_оток',
#  'Държавен_вестник',
#  'Държавен_съвет_на_Народна_република_България',
#  'Европейска_централна_банка',
#  'Железният_човек',
#  'Закон_за_трудовата_поземлена_собственост',
#  'Златен_глобус',
#  'Иван_Славков',
#  'Изобразително_изкуство',
#  'Интегрална_схема',
#  'Интел',
#  'Ирландия',
#  'Капитан_Америка',
#  'Княжество_България',
#  'Конституционен_съд_на_България',
#  'Крис_Евънс',
#  'Леброн_Джеймс',
#  'Лека_атлетика',
#  'Лукойл_Нефтохим_Бургас',
#  'Майкъл_Фелпс',
#  'Марк_Ръфало',
#  'Международна_автомобилна_федерация',
#  'Метро_Груп',
#  'Микроелектроника',
#  'Микропроцесор',
#  'Мила_Кунис',
#  'Министерство_на_външните_работи_на_България',
#  'Мобилно_устройство',
#  'Модерно_семейство',
#  'Музикален_продуцент',
#  'НАТО',
#  'Награди_на_филмовата_академия_на_САЩ',
#  'Народно_събрание',
#  'Национална_баскетболна_асоциация',
#  'Нетфликс',
#  'Оксфордски_университет',
#  'Октомврийска_революция',
#  'Олимпийски_игри',
#  'Операционна_система',
#  'Орден_на_Британската_империя',
#  'Остромила',
#  'Открито_първенство_на_Франция',
#  'Пейо_Яворов',
#  'Планова_икономика',
#  'Пловдивски_университет',
#  'Практикер',
#  'Програмна_грешка',
#  'Прототип',
#  'Реклама',
#  'Република_Кипър',
#  'Робърт_Дауни_Джуниър',
#  'Сам_вкъщи',
#  'Световна_организация_за_интелектуална_собственост',
#  'Силициева_долина',
#  'Скарлет_Йохансон',
#  'Софтуер_с_отворен_код',
#  'Старокаменна_епоха',
#  'Стефка_Костадинова',
#  'Стокхолмски_синдром',
#  'Съюз_на_българските_автомобилисти',
#  'ТАБСО',
#  'Табулираща_машина',
#  'Транзистор',
#  'Тримерен_печат',
#  'Уеб_сървър',
#  'Уебстраница',
#  'ФК_Ювентус',
#  'Фестивал',
#  'Формула_1',
#  'Хановер',
#  'Хокей_на_лед',
#  'Хоум_Бокс_Офис',
#  'Христо_Ботев',
#  'Хълк',
#  'Хърватия',
#  'Чип',
#  'Шампионска_лига_на_УЕФА'}

# %%
# pd.set_option('display.max_rows', None)
# clean_annotations[clean_annotations['doc_id'] =='Waterschapsverkiezingen'].sort_values(by='acronym')

# %%
clean_annotations.drop_duplicates(keep='last').to_csv('./clean_data/clean_annotations_without_duplicates.csv', index=False)

# %%
bulgarian_dataset = {}
for annotation in clean_annotations.iterrows():
    if bulgarian_dataset.get(annotation[1]['doc_id']) == None:
        if annotation[1]['type'] == 'in_expansion':
            bulgarian_dataset[annotation[1]['doc_id']] = {}
            if bulgarian_dataset[annotation[1]['doc_id']].get('in_expansion') == None:
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'] = {}
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
            else:
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
        else:
            bulgarian_dataset[annotation[1]['doc_id']] = {}
            if bulgarian_dataset[annotation[1]['doc_id']].get('out_expansion') == None:
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'] = {}
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
            else:
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
    else:
        if annotation[1]['type'] == 'in_expansion':
            if bulgarian_dataset[annotation[1]['doc_id']].get('in_expansion') == None:
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'] = {}
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
            else:
                bulgarian_dataset[annotation[1]['doc_id']]['in_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
        else:
            if bulgarian_dataset[annotation[1]['doc_id']].get('out_expansion') == None:
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'] = {}
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']
            else:
                bulgarian_dataset[annotation[1]['doc_id']]['out_expansion'][annotation[1]['expansion']] = annotation[1]['acronym']


print (bulgarian_dataset)
# Out:
# {'Conus_eugrammatus': {'out_expansion': {'meter': 'm', 'Celsius': '°C', 'Китайската народна република': 'КНР', 'Съединени Американски Щати': 'САЩ'}}, 'JavaScript': {'out_expansion': {'ECMAScript 6': 'ES6', 'HyperText Markup Language': 'HTML', 'JavaScript Object Notation': 'JSON', 'Съединени американски щати': 'САЩ', 'година': 'г.', 'тоест': 'т.е.', 'Microsoft Visual Basic Scripting Edition': 'VBScript'}}, 'UML': {'in_expansion': {'Object Management Group': 'OMG'}, 'out_expansion': {'Object-modeling technique': 'OMT', 'Object-Oriented Software Engineering': 'OOSE', 'Unified Modeling Language': 'UML', 'Информационните технологии': 'ИТ', 'International Business Machines Corporation': 'IBM', 'Съединени американски щати': 'САЩ'}}, 'Административен_акт': {'in_expansion': {'Административнопроцесуалния кодекс': 'АПК'}, 'out_expansion': {'Държавен вестник': 'ДВ', 'алинея': 'ал.', 'брой': 'бр.', 'тоест': 'т.е.', 'член': 'чл.'}}, 'Акционерно_дружество': {'in_expansion': {'Акционерно дружество': 'АД', 'еднолично акционерно дружество': 'ЕАД'}}, 'Американска_психологична_асоциация': {'in_expansion': {'Американската психологична асоциация': 'АПА'}, 'out_expansion': {'Съединените Американски Щати': 'САЩ', 'милион': 'млн.'}}, 'Амстердамски_университет': {'out_expansion': {'Висше учебно заведение': 'ВУЗ', 'година': 'г.', 'милиона': 'млн.', 'хиляди': 'хил.'}}, 'Банкова_консолидационна_компания': {'in_expansion': {'Банковата консолидационна компания': 'БКК'}, 'out_expansion': {'Движение за права и свободи': 'ДПС', 'Държавна спестовна каса': 'ДСК', 'Национално движение за стабилност и възход': 'НДСВ', 'година': 'г.', 'град': 'гр.', 'милиард': 'млрд.', 'пощенски код': 'п.к.', 'улица': 'ул.'}}, 'Баркод': {'out_expansion': {'two dimensional': '2D', 'International Standard Book Number': 'ISBN', 'International Standard Serial Number': 'ISSN', 'Interleaved Two of Five': 'ITF', 'quick response code': 'QR', 'United States': 'US', 'Европейски номер на артикула': 'ЕАН', 'Съединени Американски Щати': 'САЩ', 'година': 'г.'}, 'in_expansion': {'European Article Numbering': 'EAN', 'Uniform Code Council': 'UCC', 'Universal Product Code': 'UPC', 'Българска търговско-промишлена палата': 'БТПП'}}, 'Берлин': {'out_expansion': {"Women's Tennis Association": 'WTA', 'kilometer': 'km', 'Square kilometer': 'km²', 'meter': 'm', 'Celsius': '°C', 'Брутен вътрешен продукт': 'БВП', 'Висше учебно заведени': 'ВУЗ', 'Германска демократична република': 'ГДР', 'Съединени Американски Щати': 'САЩ', 'спортен клуб': 'СК', 'Съюз на съветските социалистически републики': 'СССР', 'Футболен клуб': 'ФК', 'Организация на Обединените нации по въпросите на образованието, науката и културата': 'ЮНЕСКО', 'година': 'г.', 'милиард': 'млрд.', 'преди новата ера': 'пр.н.е.'}, 'in_expansion': {'Европейския съюз': 'ЕС'}}, 'Би_Би_Си': {'out_expansion': {'British Broadcasting Corporation': 'BBC', 'Българска академия на науките': 'БАН', 'академик': 'акад.', 'година': 'г.', 'други': 'др.'}}, 'Би_Ти_Ви': {'out_expansion': {'British Broadcasting Corporation': 'BBC', 'High Definition': 'HD', 'Internet Protocol television': 'IPTV', 'Multiplexer': 'MUX', 'Standard definition': 'SD', 'Акционерно дружество': 'АД', 'Еднолично акционерно дружество': 'ЕАД', 'Министерски съвет': 'МС', 'Национален дворец на културата': 'НДК', 'Дружество с ограничена отговорност': 'ООД', 'Подвижна телевизионна станция': 'ПТС', 'Съюзът на европейските футболни асоциации': 'УЕФА', 'алинея': 'ал.', 'година': 'г.', 'точка': 'т.', 'член': 'чл.'}, 'in_expansion': {'Държавната комисия по далекосъобщения': 'ДКД', 'Комисия по регулиране на съобщенията': 'КРС', 'Съветът за електронни медии': 'СЕМ', 'Central European Media Enterprises': 'СМЕ'}}, 'БНТ_1': {'out_expansion': {'Digital Video Broadcasting - Terrestrial': 'DVB-T', 'High Definition': 'HD', 'Българската национална телевизия': 'БНТ', 'година': 'г.'}}, 'БНТ_2': {'in_expansion': {'Българската национална телевизия': 'БНТ'}, 'out_expansion': {'Регионален телевизионен център': 'РТВЦ', 'година' ...
